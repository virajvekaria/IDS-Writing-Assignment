# %% [markdown]
# # World Inequality Database Dataset

# %% [markdown]
# ---------------------------------

# %% [markdown]
# ## Content of this Folder

# %% [markdown]
# In addition to the current README file, this folder contains the following CSV files:
#
# * "WID_countries.csv" which contains the list and meaning of all country and region codes.
#
# * file(s) named "WID_data_XX.csv" which contains the data for the country/region XX.
#
# * file(s) named "WID_metadata_XX.csv" which contains the metadata for the country/region XX.
#
# ## Structure and Format of the CSV files
#
# The CSV files use the semicolon ";" as a separator. Strings are quoted when required. The first row corresponds to variable names.
#
# ## Structure of WID_countries.csv file
#
# The WID_countries.csv file contains five variables:
#
# * alpha2: the 2-letter country/region code. It mostly follows the ISO 3166-1 alpha-2 nomenclature, with some additions to account for former countries, regions and subregions. Regions within country XX are indicated as XX-YY, where YY is the region code. World regions are indicated as XX and XX-MER, the first one using purchasing power parities (the default) and the second one using market exchange rates. See [the technical note "Prices and currency conversions in WID.world"](https://wid.world/document/convert-wid-world-series/) for details.
#
# * titlename: the name of the country/region as it would appear in an English sentence (i.e. including the definite article, if any).
#
# * shortname: the name of the country/region as it would appear on its own in English (i.e. excluding the definite article).
#
# * region: broad world region to which the country belongs (similar to the first-level division of the United Nations geoscheme).
#
# * region2: detailed world region to which the country belongs (similar to the second-level division of the United Nations geoscheme).
#
# ## Structure of the WID_data_XX.csv files
#
# The WID_data_XX.csv files contain seven variables:
#
# * country: country/region code (see WID_countries.csv).
#
# * variable: WID variable code (see below for details).
#
# * percentile: WID percentile code (see below for details).
#
# * year: the year of the data point.
#
# * value: the value of the data point.
#
# * age: code indicating the age group to which the data point refers to.
#
# * pop: code indicating the population unit to which the data point refers to.
#
# ## Structure of the WID_metadata_XX.csv
#
# The WID_metadata_XX.csv contains seventeen variables:
#
# * country: the country/region code.
#
# * variable: the variable code to which the metadata refer.
#
# * age: the code of the age group to which the population refer.
#
# * pop: the code of the population unit to which the population refer.
#
# * countryname: the name of the country/region as it would appear in an English sentence.
#
# * shortname: the name of the country/region as it would appear on its own in English.
#
# * simpledes: decription of the variable in plain English.
#
# * technicaldes: description of the variable via accounting identities.
#
# * shorttype: short description of the variable type (average, aggregate, share, index, etc.) in plain English.
#
# * longtype: longer, more detailed description of the variable type in plain English.
#
# * shortpop: short description of the population unit (individuals, tax units, equal-split, etc.) in plain English.
#
# * longpop: longer, more detailed description of the population unit in plain English.
#
# * shortage: short description of the age group (adults, full population, etc.) in plain English.
#
# * longage: longer, more detailed description of the age group in plain English.
#
# * unit: unit of the variable (the 3-letter currency code for monetary amounts).
#
# * source: The source(s) used to compute the data.
#
# * method: Methological details describing how the data was constructed and/or caveats.

# %% [markdown]
# ## How to Interpret Variable Codes
#
# The meaning of each variable is described in the metadata files. The complete WID variable codes (i.e. sptinc992j) obey to the following logic:
#
# * the first letter indicates the variable type (i.e. "s" for share).
#
# * the next five letters indicate the income/wealth/other concept (i.e. "ptinc" for pre-tax national income).
#
# * the next three digits indicate the age group (i.e. "992" for adults).
#
# * the last letter indicate the population unit (i.e. "j" for equal-split).
#
# ## How to Interpret Percentile Codes
#
# There are two types of percentiles on WID.world : (1) group percentiles and (2) generalized percentiles. The interpretation of income (or wealth) average, share or threshold series depends on which type of percentile is looked at.
#
# ## Group Percentiles
#
# Group percentiles are defined as follows : p0p50 (bottom 50% of the population), p50p90 (next 40%), p90p100 (top 10%), p99p100 (top 1%), p0p10 (bottom 10% of the population, i.e. first decile), p10p20 (next 10%, i.e. second decile), p20p30 (next 10%, i.e. third decile), p30p40 (next 10%, i.e. fourth decile), p40p50 (next 10%, i.e. fifth decile), p50p60 (next 10%, i.e. sixth decile), p60p70 (next 10%, i.e. seventh decile), p70p80 (next 10%, i.e. eighth decile), p80p90 (next 10%, i.e. ninth decile), p0p90 (bottom 90%), p0p99 (bottom 99% of the population), p99.9p100 (top 0.1%), p99.99p100 (top 0.01%).
#
# For each group percentiles, we provide the associated income or wealth shares, averages and thresholds.
#
# * group percentile shares correspond to the income (or wealth) share held by a given group percentile. For instance, the fiscal income share of group p0p50 is the share of total fiscal income captured by the bottom 50% group.
#
# * group percentile averages correspond to the income or wealth annual income (or wealth) average within a given group percentile group. For instance, the fiscal income average of group p0p50 is the average annual fiscal income of the bottom 50% group.
#
# * group percentile thresholds correspond to the minimum income (or wealth) level required to belong to a given group percentile. For instance, the fiscal income threshold of group p90p100 is the minimum annual fiscal income required to belong to the top 10% group.
#
# When the data allows, the WID.world website makes it possible to produce shares, averages and thresholds for any group percentile (say, for instance, average income of p43p99.92). These are not stored in bulk data tables.
#
# For certain countries, because of data limitations, we are not able to provide the list of group percentiles described above. We instead store specific group percentiles (these can be, depending on the countries p90p95, p95p100, p95p99, p99.5p100, p99.5p99.9, p99.75p100, p99.95p100, p99.95p99.99, p99.995p100, p99.9p99.95, p99.9p99.99 or p99p99.5).
#
# ## Generalized Percentiles
#
# Generalized percentiles (g-percentiles) are defined to as follows: p0, p1, p2, ..., p99, p99.1, p99.2, ..., p99.9, p99.91, p99.92, ..., p99.99, p99.991, p99.992 ,..., p99.999. There are 127 g-percentiles in total.
#
# For each g-percentiles, we provide shares, averages, top averages and thresholds.
#
# * g-percentiles shares correspond to the income (or wealth) share captured by the population group above a given g-percentile value. For example, the fiscal income share of g-percentile p90 corresponds to the fiscal income share held by the top 10% group; the fiscal income share of g-percentile p99.9 corresponds to the fiscal income share of the top 0.1% income group and so on. By construction, the fiscal income share of g-percentile p0 corresponds to the share held by 100% of the population and is equal to 100%. Formally, the g-percentile share at g-percentile pX corresponds to the share of the top (100-X)% group.
#
# * g-percentile averages correspond to the average income or wealth between two consecutive g-percentiles. Average income of g-percentile p0 corresponds to the average annual income of the bottom 1% group, p2 corresponds to the next 1% group and so on until p98 (the 1% population group below the top 1%). Average income of g-percentile p99 corresponds to average annual of group percentile p99p99.1 (i.e. the bottom 10% group of earners within the top 1% group of earners), p99.1 corresponds to the next 0.1% group, p99.2 corresponds to the next 0.1% group and so on until p99.8. Average income of p99.9 corresponds to the average annual income of group percentile p99.9p99.91 (i.e. the bottom 10% group of earners within the top 0.1% group of earners), p99.91 corresponds to the next 0.01% group, p99.92 corresponds to the next 0.01% group and so on until p99.98. Average income of p99.99, corresponds to the average annual income of group percentile p99.99p99.991 (i.e. the bottom 10% group within the top 0.01% group of earners), p99.991 corresponds to the next 0.001%, p99.992 corresponds to the next 0.001% group and so on until p99.999 (average income of the top 0.001% group). For instance, average fiscal income of g-percentile p50 is equal to the average annual fiscal income of the p50p51 group percentile (i.e. the average annual income of the population group earning more than 50% of the population and less than the top 49% of the population). The average fiscal income of g-percentile p99 is equal to the average annual fiscal income within group percentile p99p99.1 (i.e. a group representing 0.1% of the total population earning more than 99% of the population but less than the top 0.9% of the population).
#
# * g-percentile top-averages correspond to the average income or wealth above a given g-percentile threshold. For instance the top average fiscal income at g-percentile p50 corresponds to the average annual fiscal income of individuals earning more than 50% of the population. The top average fiscal income at g-percentile p90 corresponds to the average annual fiscal income of the top 10% group.
#
# * g-percentile thresholds correspond to minimum income (or wealth) level  required to belong to the population group above a given g-percentile value. For instance, the fiscal income threshold at g-percentile p90 corresponds to the minimum annual fiscal income required to belong to the top 10% group. Fiscal income threshold at g-percentile p99.9 corresponds to the minimum annual fiscal income required to belong to the top 0.1% group. Formally, the g-percentile threshold at g-percentile pX corresponds to the threshold of the top (100-X)% group.

# %% [markdown]
# ---

# %% [markdown]
# # Load data:

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Set visualization style
plt.style.use('fivethirtyeight')
sns.set_palette("deep")

# Function to load WID data
def load_wid_data(country_code):
    """
    Load WID data for a specific country
    
    Parameters:
    country_code (str): Two-letter country code (e.g., 'US', 'FR')
    
    Returns:
    tuple: (data_df, metadata_df, country_info)
    """
    # Load country information
    countries_df = pd.read_csv(r"dataset\WID_countries.csv", sep=';')
    country_info = countries_df[countries_df['alpha2'] == country_code].iloc[0]
    
    # Load data and metadata
    data_df = pd.read_csv(f'dataset\WID_data_{country_code}.csv', sep=';')
    metadata_df = pd.read_csv(f'dataset\WID_metadata_{country_code}.csv', sep=';')
    
    print(f"Loaded data for {country_info['titlename']}")
    return data_df, metadata_df, country_info

# %%
#example
us_data, us_metadata, us_info = load_wid_data('US')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 2
#       1 #example
# ----> 2 us_data, us_metadata, us_info = load_wid_data('US')
#
# Cell In[1], line 22, in load_wid_data(country_code)
#      12 """
#      13 Load WID data for a specific country
#      14
#    (...)
#      19 tuple: (data_df, metadata_df, country_info)
#      20 """
#      21 # Load country information
# ---> 22 countries_df = pd.read_csv(r"dataset\WID_countries.csv", sep=';')
#      23 country_info = countries_df[countries_df['alpha2'] == country_code].iloc[0]
#      25 # Load data and metadata
#
# File c:\Users\jiyad\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\jiyad\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File c:\Users\jiyad\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\jiyad\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File c:\Users\jiyad\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'dataset\\WID_countries.csv'

# %%
us_data.head()
# Out:
#   country    variable percentile  year        value  age pop
# 0      US  ehfcari999     p0p100  1990  2284.334507  999   i
# 1      US  ehfcari999     p0p100  1991  2275.642153  999   i
# 2      US  ehfcari999     p0p100  1992  2370.115893  999   i
# 3      US  ehfcari999     p0p100  1993  2363.898468  999   i
# 4      US  ehfcari999     p0p100  1994  2384.815002  999   i

# %%
us_info.head()
# Out:
# alpha2                  US
# titlename          the USA
# shortname              USA
# region            Americas
# region2      North America
# Name: 307, dtype: object

# %% [markdown]
# ## Analyse income equality: trend of shares of top 1%, top 10%, mid 40% and bottom 10% of the total adult population in the country's total pre-tax income

# %%
# Function to analyze income inequality trends
def analyze_income_inequality(data_df, country_name, start_year=1980, end_year=2023):
    """
    Analyze income inequality trends for a country
    
    Parameters:
    data_df (DataFrame): WID data
    country_name (str): Name of the country for plot titles
    start_year (int): Starting year for analysis
    end_year (int): Ending year for analysis
    """
    # Filter for pre-tax income share data for key percentile groups
    income_vars = data_df[data_df['variable'].str.startswith('sptinc')]
    
    # Select key percentile groups
    percentile_groups = ['p0p50', 'p50p90', 'p90p100', 'p99p100']
    income_data = income_vars[income_vars['percentile'].isin(percentile_groups)]
    
    # Filter for year range
    income_data = income_data[(income_data['year'] >= start_year) & 
                              (income_data['year'] <= end_year)]
    
    # Pivot data for plotting
    pivot_data = income_data.pivot_table(
        index='year', 
        columns='percentile', 
        values='value'
    ).reset_index()
    
    # Create plot
    plt.figure(figsize=(12, 8))
    
    plt.plot(pivot_data['year'], pivot_data['p0p50'], 
             linewidth=3, label='Bottom 50%')
    plt.plot(pivot_data['year'], pivot_data['p50p90'], 
             linewidth=3, label='Middle 40%')
    plt.plot(pivot_data['year'], pivot_data['p90p100'], 
             linewidth=3, label='Top 10%')
    plt.plot(pivot_data['year'], pivot_data['p99p100'], 
             linewidth=3, label='Top 1%')
    
    plt.title(f'Income Inequality Trends in {country_name} ({start_year}-{end_year})', 
              fontsize=16)
    plt.xlabel('Year', fontsize=14)
    plt.ylabel('Share of National Income (%)', fontsize=14)
    plt.legend(fontsize=12)
    plt.grid(True, alpha=0.3)
    
    plt.tight_layout()
    plt.show()
    
    # Calculate and print summary statistics
    latest_year = pivot_data['year'].max()
    earliest_year = pivot_data['year'].min()
    
    latest_data = pivot_data[pivot_data['year'] == latest_year].iloc[0]
    earliest_data = pivot_data[pivot_data['year'] == earliest_year].iloc[0]
    
    print(f"\nIncome Inequality Summary for {country_name}:")
    print(f"Period: {earliest_year} to {latest_year}")
    print("\nShare of National Income:")
    
    for group in percentile_groups:
        group_name = {
            'p0p50': 'Bottom 50%',
            'p50p90': 'Middle 40%',
            'p90p100': 'Top 10%',
            'p99p100': 'Top 1%'
        }[group]
        
        early_val = earliest_data[group]
        late_val = latest_data[group]
        change = late_val - early_val
        
        print(f"{group_name}: {late_val:.1f}% ({'+' if change > 0 else ''}{change:.1f}pp change)")

# %%
# 2. Analyze income inequality trends
analyze_income_inequality(us_data, us_info['shortname'])
# Out:
# Income Inequality Summary for USA:
# Period: 1980 to 2020
#
# Share of National Income:
# Bottom 50%: 0.1% (-0.0pp change)
# Middle 40%: 0.4% (-0.1pp change)
# Top 10%: 0.4% (+0.1pp change)
# Top 1%: 0.2% (+0.1pp change)

# %% [markdown]
# ## Comparing countries by their share of top 1% of the population in the country's total pre-tax income (can be extended to a time-series animation)

# %%
# Function to compare countries
def compare_countries(country_codes, year=2020, percentile='p99p100'):
    """
    Compare income inequality across countries
    
    Parameters:
    country_codes (list): List of country codes to compare
    year (int): Year for comparison
    percentile (str): Percentile group to compare
    """
    countries_df = pd.read_csv('dataset\WID_countries.csv', sep=';')
    
    results = []
    
    for code in country_codes:
        try:
            # Load data
            data_df = pd.read_csv(f'dataset\WID_data_{code}.csv', sep=';')
            country_info = countries_df[countries_df['alpha2'] == code].iloc[0]
            
            # Filter for income share data for the specified percentile and year
            income_data = data_df[
                (data_df['variable'].str.startswith('sptinc')) & 
                (data_df['percentile'] == percentile) &
                (data_df['year'] == year)
            ]
            
            if not income_data.empty:
                results.append({
                    'country': country_info['shortname'],
                    'value': income_data['value'].iloc[0]
                })
            
        except Exception as e:
            print(f"Error processing {code}: {e}")
    
    # Create DataFrame and sort
    results_df = pd.DataFrame(results)
    results_df = results_df.sort_values('value', ascending=False)
    
    # Create bar plot
    plt.figure(figsize=(12, 8))
    
    sns.barplot(x='value', y='country', data=results_df)
    
    percentile_name = {
        'p0p50': 'Bottom 50%',
        'p50p90': 'Middle 40%',
        'p90p100': 'Top 10%',
        'p99p100': 'Top 1%',
        'p99.9p100': 'Top 0.1%'
    }.get(percentile, percentile)
    
    plt.title(f'Income Share of {percentile_name} Across Countries ({year})', fontsize=16)
    plt.xlabel('Share of National Income (%)', fontsize=14)
    plt.ylabel('Country', fontsize=14)
    plt.grid(True, alpha=0.3)
    
    plt.tight_layout()
    plt.show()

# %%
# 3. Compare top 1% income share across countries
compare_countries(['US', 'FR', 'GB', 'DE', 'JP', 'CN', 'IN'], percentile='p99p100')

# %%
pip install ipywidgets IPython
# Out:
# Requirement already satisfied: ipywidgets in c:\users\jiyad\appdata\local\programs\python\python311\lib\site-packages (8.1.6)
# Requirement already satisfied: IPython in c:\users\jiyad\appdata\roaming\python\python311\site-packages (8.19.0)
# Requirement already satisfied: comm>=0.1.3 in c:\users\jiyad\appdata\roaming\python\python311\site-packages (from ipywidgets) (0.2.1)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\jiyad\appdata\roaming\python\python311\site-packages (from ipywidgets) (5.14.1)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in c:\users\jiyad\appdata\local\programs\python\python311\lib\site-packages (from ipywidgets) (4.0.14)
# Requirement already satisfied: jupyterlab_widgets~=3.0.14 in c:\users\jiyad\appdata\local\programs\python\python311\lib\site-packages (from ipywidgets) (3.0.14)
# Requirement already satisfied: decorator in c:\users\jiyad\appdata\roaming\python\python311\site-packages (from IPython) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\jiyad\appdata\roaming\python\python311\site-packages (from IPython) (0.19.1)
# Requirement already satisfied: matplotlib-inline in c:\users\jiyad\appdata\roaming\python\python311\site-packages (from IPython) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\jiyad\appdata\roaming\python\python311\site-packages (from IPython) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\jiyad\appdata\roaming\python\python311\site-packages (from IPython) (2.17.2)
# Requirement already satisfied: stack-data in c:\users\jiyad\appdata\roaming\python\python311\site-packages (from IPython) (0.6.3)
# Requirement already satisfied: colorama in c:\users\jiyad\appdata\roaming\python\python311\site-packages (from IPython) (0.4.6)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\jiyad\appdata\roaming\python\python311\site-packages (from jedi>=0.16->IPython) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\jiyad\appdata\roaming\python\python311\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->IPython) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in c:\users\jiyad\appdata\roaming\python\python311\site-packages (from stack-data->IPython) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\jiyad\appdata\roaming\python\python311\site-packages (from stack-data->IPython) (2.4.1)
# Requirement already satisfied: pure-eval in c:\users\jiyad\appdata\roaming\python\python311\site-packages (from stack-data->IPython) (0.2.2)
# Requirement already satisfied: six>=1.12.0 in c:\users\jiyad\appdata\local\programs\python\python311\lib\site-packages (from asttokens>=2.1.0->stack-data->IPython) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## Time-series of the above trend (some issue with the generated plots - on hold)

# %%
# %matplotlib notebook

# %%
# # import pandas as pd
# # import matplotlib.pyplot as plt
# # import seaborn as sns
# # from matplotlib.animation import FuncAnimation
# # from IPython.display import HTML

# # def animate_inequality(country_codes, percentile='p99p100', years=range(2000, 2021)):
# #     countries_df = pd.read_csv('dataset/WID_countries.csv', sep=';')
# #     country_info = {code: countries_df[countries_df['alpha2'] == code].iloc[0]['shortname'] for code in country_codes}

# #     # Load and filter all data
# #     data = []
# #     for code in country_codes:
# #         try:
# #             df = pd.read_csv(f'dataset/WID_data_{code}.csv', sep=';')
# #             df['year'] = df['year'].astype(int)
# #             df = df[(df['variable'].str.startswith('sptinc')) &
# #                     (df['percentile'] == percentile) &
# #                     (df['year'].isin(years))]
# #             df['country'] = country_info[code]
# #             data.append(df[['year', 'value', 'country']])
# #         except Exception as e:
# #             print(f"Error loading {code}: {e}")
    
# #     if not data:
# #         print("No data available after filtering.")
# #         return

# #     all_data = pd.concat(data)
# #     all_data = all_data.sort_values(by=['year', 'value'], ascending=[True, False])

# #     fig, ax = plt.subplots(figsize=(10, 6))

# #     def update(year):
# #         ax.clear()
# #         year_data = all_data[all_data['year'] == year]
# #         sns.barplot(x='value', y='country', data=year_data, ax=ax)
# #         ax.set_title(f'Income Share of {percentile} in {year}', fontsize=16)
# #         ax.set_xlabel('Share of National Income (%)')
# #         ax.set_ylabel('Country')
# #         ax.grid(True, alpha=0.3)
# #         ax.set_xlim(0, all_data['value'].max() * 1.1)  # consistent axis scaling

# #     anim = FuncAnimation(fig, update, frames=sorted(all_data['year'].unique()), interval=1000, repeat=True)

# #     plt.close(fig)  # Prevent static duplicate plot
# #     return HTML(anim.to_jshtml())

# import pandas as pd
# import matplotlib.pyplot as plt
# import seaborn as sns
# from matplotlib.animation import FuncAnimation
# from IPython.display import HTML

# def animate_inequality(country_codes, percentile='p99p100', years=range(2000, 2021)):
#     countries_df = pd.read_csv('dataset/WID_countries.csv', sep=';')
#     country_info = {code: countries_df[countries_df['alpha2'] == code].iloc[0]['shortname'] for code in country_codes}

#     # Load and filter all data
#     data = []
#     for code in country_codes:
#         try:
#             df = pd.read_csv(f'dataset/WID_data_{code}.csv', sep=';')
#             df['year'] = df['year'].astype(int)
#             df = df[(df['variable'].str.startswith('sptinc')) &
#                     (df['percentile'] == percentile) &
#                     (df['year'].isin(years))]
#             df['country'] = country_info[code]
#             data.append(df[['year', 'value', 'country']])
#         except Exception as e:
#             print(f"Error loading {code}: {e}")
    
#     if not data:
#         print("No data available after filtering.")
#         return

#     all_data = pd.concat(data)

#     # Ensure consistent country order (based on initial input list)
#     country_order = [country_info[code] for code in country_codes]

#     fig, ax = plt.subplots(figsize=(12, 5))

#     def update(year):
#         ax.clear()
#         year_data = all_data[all_data['year'] == year]
#         sns.barplot(x='value', y='country', data=year_data, ax=ax, order=country_order, ci=None)
#         ax.set_title(f'Income Share of Top 1% across countries in {year}', fontsize=14)
#         ax.set_xlabel('Share of National Income (%)')
#         ax.set_ylabel('Country')
#         ax.grid(True, alpha=0.3)
#         ax.set_xlim(0, all_data['value'].max() * 1.1)
#         plt.tight_layout()

#     anim = FuncAnimation(fig, update, frames=sorted(all_data['year'].unique()), interval=1000, repeat=True)

#     plt.close(fig)
#     return HTML(anim.to_jshtml())

# %%
# animate_inequality(['US', 'FR', 'GB', 'DE', 'JP', 'CN', 'IN'], percentile='p90p100', years=range(2000, 2020))

# %% [markdown]
# ## Finding the top 10 countries with the highest value of the share of the country's top 1% in the pre-tax national income of the country:

# %%
import pandas as pd
import os
import glob
from datetime import datetime

# Function to get the most recent year data for top 1% pre-tax national income share for each country
def get_top_countries_by_income_inequality():
    # Get list of all data files
    data_files = glob.glob("dataset\WID_data_*.csv")
    
    # Initialize empty list to store results
    results = []
    
    # Define the target variable for top 1% pre-tax national income share
    # Based on WID documentation:
    # "s" for share
    # "ptinc" for pre-tax national income
    # The percentile code for top 1% is "p99p100"
    target_variable = "sptinc"
    target_percentile = "p99p100"
    
    # Process each country file
    for file in data_files:
        country_code = file.split("_")[2].split(".")[0]
        
        try:
            # Read the data with proper delimiter
            df = pd.read_csv(file, delimiter=";")
            
            # Filter for the target variable and percentile
            filtered_df = df[(df['variable'].str.startswith(target_variable)) & 
                            (df['percentile'] == target_percentile)]
            
            if not filtered_df.empty:
                # Get the most recent year
                most_recent_year = filtered_df['year'].max()
                
                # Get the value for the most recent year
                latest_data = filtered_df[filtered_df['year'] == most_recent_year]
                
                if not latest_data.empty:
                    # Get country name from the countries file
                    countries_df = pd.read_csv("dataset\WID_countries.csv", delimiter=";")
                    country_name = countries_df[countries_df['alpha2'] == country_code]['shortname'].values
                    
                    country_name = country_name[0] if len(country_name) > 0 else country_code
                    
                    # Add to results
                    results.append({
                        'country_code': country_code,
                        'country': country_name,
                        'year': most_recent_year,
                        'top1_percent_share': latest_data['value'].values[0],
                        'variable': latest_data['variable'].values[0]
                    })
        
        except Exception as e:
            print(f"Error processing {country_code}: {e}")
    
    # Convert to DataFrame
    results_df = pd.DataFrame(results)
    
    # Sort by the top 1% share in descending order
    if not results_df.empty:
        results_df = results_df.sort_values('top1_percent_share', ascending=False)
        
        # Get top 10 countries
        top_10 = results_df.head(10)
        
        return top_10
    else:
        return pd.DataFrame()

# Main execution
if __name__ == "__main__":
    print("Finding top 10 countries with highest top 1% share of pre-tax national income...")
    top_countries = get_top_countries_by_income_inequality()
    
    if not top_countries.empty:
        print("\nTop 10 countries by top 1% income share:")
        print(top_countries[['country', 'year', 'top1_percent_share']].to_string(index=False))
        
        # Create a more detailed output with formatted percentages
        print("\nDetailed Results:")
        for _, row in top_countries.iterrows():
            print(f"{row['country']}: {row['top1_percent_share']:.2f}% (data from {int(row['year'])})")
    else:
        print("No data found. Please check that the WID data files are in the correct format and location.")
# Out:
# Finding top 10 countries with highest top 1% share of pre-tax national income...
#
# Top 10 countries by top 1% income share:
#                                                 country  year  top1_percent_share
# Other North America & Oceania (at market exchange rate)  2023              0.3225
#                                                 Florida  2018              0.3193
#                                                  Nevada  2018              0.3116
#                                                 Hamburg  1911              0.3030
#                                                New York  2018              0.2973
#                    Other MENA (at market exchange rate)  2023              0.2908
#                          MENA (at market exchange rate)  2023              0.2872
#                   Middle East (at market exchange rate)  2023              0.2850
#                                                  Bremen  1910              0.2752
#                                                    Peru  2023              0.2690
#
# Detailed Results:
# Other North America & Oceania (at market exchange rate): 0.32% (data from 2023)
# Florida: 0.32% (data from 2018)
# Nevada: 0.31% (data from 2018)
# Hamburg: 0.30% (data from 1911)
# New York: 0.30% (data from 2018)
# Other MENA (at market exchange rate): 0.29% (data from 2023)
# MENA (at market exchange rate): 0.29% (data from 2023)
# Middle East (at market exchange rate): 0.28% (data from 2023)
# Bremen: 0.28% (data from 1910)
# Peru: 0.27% (data from 2023)

# %% [markdown]
# ## Trying to read from the CSV downloaded after setting indicators on the website

# %% [markdown]
# Share of top 1% in USA's pre-tax national income from 1980 to 2023:

# %%
import pandas as pd
import csv

# Read the file with csv module
data = []
with open(r"C:\Users\jiyad\OneDrive\Desktop\IITGN\Introduction to Data Science\writing assignment\WID_Data_10042025-195315.csv", 'r') as file:
    reader = csv.reader(file, delimiter=';', quotechar='"')
    for row in reader:
        # Ensure each row has 5 elements
        while len(row) < 5:
            row.append(None)  # Add None for missing values
        data.append(row[:5])  # Take only the first 5 elements

# Convert to DataFrame
df = pd.DataFrame(data)

# Assign column names
column_names = ['country', 'variable_description', 'percentile', 'year', 'value']
df.columns = column_names

# Clean data and convert types safely
df['variable_description'] = df['variable_description'].str.replace('\n', ' ') if df['variable_description'].notna().any() else df['variable_description']

# Convert year and value, handling missing data
df['year'] = pd.to_numeric(df['year'], errors='coerce')  # NaN for non-numeric values
df['value'] = pd.to_numeric(df['value'], errors='coerce')  # NaN for non-numeric values

# Print the first few rows
print(df.head())

# Print basic info to understand the data
print("\nDataFrame info:")
print(df.info())

# Check for missing values
print("\nMissing values:")
print(df.isna().sum())
# Out:
#                                              country  \
# 0  Downloaded from wid.world on 10-04-2025 at 19:...
# 1                                               USA
# 2                                               USA
# 3                                               USA
# 4                                               USA
#
#                                 variable_description percentile    year  \
# 0                                               None       None     NaN
# 1  sptinc_p99p100_z_US Pre-tax national income  T...    p99p100  1980.0
# 2  sptinc_p99p100_z_US Pre-tax national income  T...    p99p100  1981.0
# 3  sptinc_p99p100_z_US Pre-tax national income  T...    p99p100  1982.0
# 4  sptinc_p99p100_z_US Pre-tax national income  T...    p99p100  1983.0
#
#     value
# 0     NaN
# 1  0.1042
# 2  0.1067
# 3  0.1099
# 4  0.1150
#
# DataFrame info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45 entries, 0 to 44
# Data columns (total 5 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   country               45 non-null     object
#  1   variable_description  44 non-null     object
#  2   percentile            44 non-null     object
#  3   year                  44 non-null     float64
#  4   value                 44 non-null     float64
# dtypes: float64(2), object(3)
# memory usage: 1.9+ KB
# None
#
# Missing values:
# country                 0
# variable_description    1
# percentile              1
# year                    1
# value                   1
# dtype: int64

# %%
df.head(5)
# Out:
#                                              country  \
# 0  Downloaded from wid.world on 10-04-2025 at 19:...
# 1                                               USA
# 2                                               USA
# 3                                               USA
# 4                                               USA
#
#                                 variable_description percentile    year  \
# 0                                               None       None     NaN
# 1  sptinc_p99p100_z_US Pre-tax national income  T...    p99p100  1980.0
# 2  sptinc_p99p100_z_US Pre-tax national income  T...    p99p100  1981.0
# 3  sptinc_p99p100_z_US Pre-tax national income  T...    p99p100  1982.0
# 4  sptinc_p99p100_z_US Pre-tax national income  T...    p99p100  1983.0
#
#     value
# 0     NaN
# 1  0.1042
# 2  0.1067
# 3  0.1099
# 4  0.1150

# %%
df = df.drop(index=0)

# %% [markdown]
# Final processed data:

# %%
df.head(10)
# Out:
#    country                               variable_description percentile  \
# 1     USA   sptinc_p99p100_z_US Pre-tax national income  T...    p99p100
# 2     USA   sptinc_p99p100_z_US Pre-tax national income  T...    p99p100
# 3     USA   sptinc_p99p100_z_US Pre-tax national income  T...    p99p100
# 4     USA   sptinc_p99p100_z_US Pre-tax national income  T...    p99p100
# 5     USA   sptinc_p99p100_z_US Pre-tax national income  T...    p99p100
# 6     USA   sptinc_p99p100_z_US Pre-tax national income  T...    p99p100
# 7     USA   sptinc_p99p100_z_US Pre-tax national income  T...    p99p100
# 8     USA   sptinc_p99p100_z_US Pre-tax national income  T...    p99p100
# 9     USA   sptinc_p99p100_z_US Pre-tax national income  T...    p99p100
# 10    USA   sptinc_p99p100_z_US Pre-tax national income  T...    p99p100
#
#       year   value
# 1   1980.0  0.1042
# 2   1981.0  0.1067
# 3   1982.0  0.1099
# 4   1983.0  0.1150
# 5   1984.0  0.1215
# 6   1985.0  0.1227
# 7   1986.0  0.1198
# 8   1987.0  0.1324
# 9   1988.0  0.1521
# 10  1989.0  0.1469

# %% [markdown]
# This can be used easily for analysis.

# %% [markdown]
# ## Some plots were generated using Excel for the following:
# - Comparing per-adult national income and per-adult national wealth in 2023 across all countries
# - Share of the top 1% in the country's pre-tax national income (highest to lowest, by country)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
