# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import warnings

# Ignore warnings for cleaner output
warnings.filterwarnings('ignore')
# Import functions from our exploration module
from data_exploration import read_wid_csv, explore_countries, explore_country_data, compare_variable_availability

# %%
INCOME_VARIABLES = ['aptincf992', 'adiinci992', 'aptinci992', 'gfaincj992'] 
WEALTH_VARIABLES = ['bhwealj992']
SHARE_VARIABLES = ['spllinf992']

# Define percentiles of interest (based on what's available in your dataset)
TOP_PERCENTILES = ['p90p100', 'p99p100', 'p99.9p100']  # Top 10%, Top 1%, Top 0.1%
BOTTOM_PERCENTILES = ['p0p50', 'p0p90']  # Bottom 50%, Bottom 90%
MIDDLE_PERCENTILES = ['p50p90']  # Middle 40%

# Countries to include in our analysis
# We'll select a diverse set of countries from different regions and development levels
COUNTRIES_TO_ANALYZE = [
    # High-income countries
    'US',   # United States
    'FR',   # France
    'DE',   # Germany
    'GB',   # United Kingdom
    'JP',   # Japan
    
    # Upper-middle income countries
    'BR',   # Brazil
    'CN',   # China
    'RU',   # Russia
    'ZA',   # South Africa
    
    # Lower-middle and low-income countries
    'IN',   # India
    'ID',   # Indonesia
    'NG',   # Nigeria
    'EG'    # Egypt
]

# %%
# Function to load country data with selected variables
def load_country_data(country_code, directory='wid_all_data'):
    """
    Load specific inequality variables for a given country.
    
    Args:
        country_code (str): Two-letter country code
        directory (str): Path to WID data directory
    
    Returns:
        tuple: (data_df, metadata_df) for the country
    """
    data_path = os.path.join(directory, f'WID_data_{country_code}.csv')
    metadata_path = os.path.join(directory, f'WID_metadata_{country_code}.csv')
    
    if not os.path.exists(data_path) or not os.path.exists(metadata_path):
        print(f"Data or metadata not found for {country_code}")
        return None, None
    
    data_df = read_wid_csv(data_path)
    metadata_df = read_wid_csv(metadata_path)
    
    return data_df, metadata_df

# Function to create a dataset for a specific inequality metric
def create_inequality_dataset(countries, variable_codes, percentiles, directory='wid_all_data'):
    """
    Create a dataset comparing specific inequality variables across countries.
    Will try each variable code in the list until one works.
    
    Args:
        countries (list): List of country codes
        variable_codes (list or str): WID variable code(s) to try
        percentiles (list): List of percentile codes (e.g., ['p99p100', 'p0p50'])
        directory (str): Path to WID data directory
    
    Returns:
        pd.DataFrame: Combined dataset with inequality data
    """
    # Convert single variable code to list for consistent processing
    if isinstance(variable_codes, str):
        variable_codes = [variable_codes]
    
    # Load country information for names
    countries_info = explore_countries(directory)
    if countries_info is None:
        print("Could not load country information")
        return None
    
    countries_df = countries_info['countries_df']
    country_name_map = dict(zip(countries_df['alpha2'], countries_df['shortname']))
    
    # Try each variable code until we find one that works
    for variable_code in variable_codes:
        print(f"Trying variable code: {variable_code}")
        combined_df = pd.DataFrame()
        
        for country in countries:
            data_df, metadata_df = load_country_data(country, directory)
            
            if data_df is None:
                print(f"  Skipping {country} - could not load data")
                continue
            
            # Filter for the requested variable and percentiles
            filtered_df = data_df[(data_df['variable'] == variable_code) & 
                                (data_df['percentile'].isin(percentiles))]
            
            if filtered_df.empty:
                print(f"  No data for {variable_code} with percentiles {percentiles} in {country}")
                continue
            
            # Add country name
            filtered_df['country_code'] = country
            filtered_df['country_name'] = country_name_map.get(country, country)
            
            # Append to combined dataset
            combined_df = pd.concat([combined_df, filtered_df])
            print(f"  Found data for {variable_code} for {country}: {len(filtered_df)} rows")
        
        if not combined_df.empty:
            print(f"Successfully found data for variable {variable_code}")
            return combined_df
    
    print(f"No data found for any of these variables: {variable_codes} across specified countries and percentiles")
    return None

# Function to create a comparative dataset of income/wealth distribution over time
def create_time_series_dataset(variable_codes, percentile, countries=COUNTRIES_TO_ANALYZE, directory='wid_all_data'):
    """
    Create a dataset of inequality metrics over time for multiple countries.
    Will try multiple variable codes until one works.
    
    Args:
        variable_codes (list or str): WID variable code(s) to try
        percentile (str): Percentile code
        countries (list): List of country codes
        directory (str): Path to WID data directory
    
    Returns:
        pd.DataFrame: Time series data for the specified variable and percentile
    """
    # Convert single variable code to list for consistent processing
    if isinstance(variable_codes, str):
        variable_codes = [variable_codes]
    
    # Get variable description (try to get from first variable code, but not critical)
    variable_desc = None
    try:
        sample_country = countries[0]
        _, metadata_df = load_country_data(sample_country, directory)
        
        if metadata_df is not None:
            for var_code in variable_codes:
                var_info = metadata_df[metadata_df['variable'] == var_code]
                if not var_info.empty:
                    variable_desc = var_info.iloc[0]['simpledes']
                    break
    except:
        pass
    
    # Try to create dataset with any of the provided variable codes
    dataset = create_inequality_dataset(countries, variable_codes, [percentile], directory)
    
    if dataset is not None:
        # Pivot to have years as columns and countries as rows for easier plotting
        dataset = dataset.sort_values(['country_name', 'year'])
        
        # Add metadata
        dataset.attrs['variable_code'] = dataset['variable'].iloc[0]  # Use the actual variable code that worked
        dataset.attrs['variable_desc'] = variable_desc
        dataset.attrs['percentile'] = percentile
    
    return dataset

# Function to create a dataset for GDP per capita
def create_gdp_dataset(countries=COUNTRIES_TO_ANALYZE, directory='wid_all_data'):
    """
    Create a dataset of GDP per capita for comparison with inequality metrics.
    Using national income per adult as a proxy.
    
    Args:
        countries (list): List of country codes
        directory (str): Path to WID data directory
    
    Returns:
        pd.DataFrame: GDP per capita data
    """
    # Try several possible GDP/income per adult variables
    gdp_variables = ['anninc992i', 'aptinc992i', 'adiinci992', 'adiincf992']
    
    # We don't need a percentile for this aggregate measure, but WID still requires one
    # p0p100 represents the entire population
    gdp_data = create_inequality_dataset(countries, gdp_variables, ['p0p100'], directory)
    
    if gdp_data is not None:
        # Add variable description
        var_code = gdp_data['variable'].iloc[0]
        gdp_data.attrs['variable_desc'] = f'Income per Adult ({var_code})'
        
        # Convert to common currency (USD) using most recent PPP rates
        # This would require additional implementation to get PPP conversion rates
        # For simplicity, we'll leave the values in local currency
    
    return gdp_data

# Function to create a cross-sectional dataset with the available variables
def create_cross_sectional_dataset(countries=COUNTRIES_TO_ANALYZE, year=2020, directory='wid_all_data'):
    """
    Create a cross-sectional dataset combining multiple inequality metrics for a specific year.
    Adapts to find available variables in the dataset.
    
    Args:
        countries (list): List of country codes
        year (int): Reference year for the cross-section
        directory (str): Path to WID data directory
    
    Returns:
        pd.DataFrame: Combined dataset with multiple inequality metrics
    """
    print("Building cross-sectional dataset with available metrics...")
    
    # Initialize results dataframe with country codes
    countries_info = explore_countries(directory)
    country_name_map = {}
    
    if countries_info is not None and 'countries_df' in countries_info:
        countries_df = countries_info['countries_df']
        country_name_map = dict(zip(countries_df['alpha2'], countries_df['shortname']))
    
    # Create the base dataframe with country information
    result_df = pd.DataFrame({
        'country_code': countries,
        'country_name': [country_name_map.get(c, c) for c in countries]
    })
    
    # Identify what variables we have available from our time series datasets
    available_datasets = []
    
    # Try loading income variables for different percentiles
    for percentile in TOP_PERCENTILES + BOTTOM_PERCENTILES:
        for var_prefix in ['a', 's']:  # Try both average and share variables
            for var_type in INCOME_VARIABLES:
                # Only use the variable type part (e.g., 'ptincf992' from 'aptincf992')
                var_base = var_type[1:] if var_type.startswith('a') or var_type.startswith('s') else var_type
                test_var = f"{var_prefix}{var_base}"
                
                dataset = create_inequality_dataset(countries, [test_var], [percentile], directory)
                if dataset is not None and not dataset.empty:
                    metric_name = f"{var_prefix}_{var_base}_{percentile}"
                    available_datasets.append({
                        'name': metric_name,
                        'dataset': dataset,
                        'variable': test_var,
                        'percentile': percentile
                    })
                    print(f"  Found data for {test_var} with percentile {percentile}")
    
    # Try loading wealth variables
    for percentile in TOP_PERCENTILES + BOTTOM_PERCENTILES:
        for wealth_var in WEALTH_VARIABLES:
            dataset = create_inequality_dataset(countries, [wealth_var], [percentile], directory)
            if dataset is not None and not dataset.empty:
                metric_name = f"{wealth_var}_{percentile}"
                available_datasets.append({
                    'name': metric_name,
                    'dataset': dataset,
                    'variable': wealth_var,
                    'percentile': percentile
                })
                print(f"  Found data for {wealth_var} with percentile {percentile}")
    
    # Try loading GDP or income per adult variables
    gdp_data = create_gdp_dataset(countries, directory)
    if gdp_data is not None and not gdp_data.empty:
        var_code = gdp_data['variable'].iloc[0]
        available_datasets.append({
            'name': f"{var_code}_per_adult",
            'dataset': gdp_data,
            'variable': var_code,
            'percentile': 'p0p100'
        })
        print(f"  Found GDP/income per adult data: {var_code}")
    
    # Extract values for the reference year (or closest available)
    for dataset_info in available_datasets:
        df = dataset_info['dataset']
        name = dataset_info['name']
        
        # Initialize new columns with NaN
        result_df[f"{name}_value"] = np.nan
        result_df[f"{name}_year"] = np.nan
        
        # Process each country
        for country in result_df['country_code']:
            country_data = df[df['country_code'] == country]
            
            if not country_data.empty:
                # Try to get the exact year first
                year_data = country_data[country_data['year'] == year]
                
                # If exact year not available, find closest year
                if year_data.empty:
                    available_years = country_data['year'].unique()
                    if len(available_years) > 0:
                        closest_year = available_years[np.abs(available_years - year).argmin()]
                        year_data = country_data[country_data['year'] == closest_year]
                
                # If we found data, add it to the result
                if not year_data.empty:
                    row_idx = result_df[result_df['country_code'] == country].index[0]
                    result_df.loc[row_idx, f"{name}_value"] = year_data['value'].iloc[0]
                    result_df.loc[row_idx, f"{name}_year"] = year_data['year'].iloc[0]
    
    # Add region information if available
    if countries_info is not None and 'countries_df' in countries_info:
        countries_df = countries_info['countries_df']
        
        for idx, row in result_df.iterrows():
            country_info = countries_df[countries_df['alpha2'] == row['country_code']]
            if not country_info.empty:
                result_df.loc[idx, 'region'] = country_info['region'].iloc[0]
                result_df.loc[idx, 'region2'] = country_info['region2'].iloc[0]
    
    # Display summary of metrics found
    value_cols = [col for col in result_df.columns if col.endswith('_value')]
    print(f"Created cross-sectional dataset with {len(value_cols)} metrics for {len(result_df)} countries")
    
    return result_df

# Function to create a dataset comparing changes in inequality over time
def create_inequality_change_dataset(countries=COUNTRIES_TO_ANALYZE, 
                                     variable_codes=INCOME_VARIABLES,
                                     percentile='p99p100', 
                                     start_year=1980, 
                                     end_year=2020,
                                     directory='wid_all_data'):
    """
    Create a dataset showing changes in inequality metrics over time.
    
    Args:
        countries (list): List of country codes
        variable_codes (list or str): WID variable code(s) to try
        percentile (str): Percentile code
        start_year (int): Starting year for change calculation
        end_year (int): Ending year for change calculation
        directory (str): Path to WID data directory
    
    Returns:
        pd.DataFrame: Dataset with inequality changes
    """
    # Get the time series data
    time_series = create_time_series_dataset(variable_codes, percentile, countries, directory)
    
    if time_series is None:
        return None
    
    # Calculate changes
    change_data = []
    
    # Group by country
    for country, group in time_series.groupby('country_code'):
        group = group.sort_values('year')
        country_name = group['country_name'].iloc[0]
        
        # Try to get values for exact years
        start_data = group[group['year'] == start_year]
        end_data = group[group['year'] == end_year]
        
        # If exact years not available, find closest years
        if start_data.empty:
            available_years = group['year'].unique()
            closest_start = available_years[np.abs(available_years - start_year).argmin()]
            start_data = group[group['year'] == closest_start]
        
        if end_data.empty:
            available_years = group['year'].unique()
            closest_end = available_years[np.abs(available_years - end_year).argmin()]
            end_data = group[group['year'] == closest_end]
        
        # Skip if we don't have data for both periods
        if start_data.empty or end_data.empty:
            print(f"Insufficient data for {country} to calculate changes")
            continue
        
        # Calculate changes
        start_value = start_data['value'].iloc[0]
        end_value = end_data['value'].iloc[0]
        actual_start_year = start_data['year'].iloc[0]
        actual_end_year = end_data['year'].iloc[0]
        
        absolute_change = end_value - start_value
        percent_change = (absolute_change / start_value) * 100 if start_value != 0 else np.nan
        
        change_data.append({
            'country_code': country,
            'country_name': country_name,
            'start_year': actual_start_year,
            'end_year': actual_end_year,
            'start_value': start_value,
            'end_value': end_value,
            'absolute_change': absolute_change,
            'percent_change': percent_change
        })
    
    # Convert to DataFrame
    change_df = pd.DataFrame(change_data)
    
    if change_df.empty:
        return None
    
    # Add metadata
    change_df.attrs['variable_code'] = time_series.attrs.get('variable_code', '')
    change_df.attrs['variable_desc'] = time_series.attrs.get('variable_desc', '')
    change_df.attrs['percentile'] = percentile
    
    return change_df

# Function to combine income and wealth inequality data for correlation analysis
def create_correlation_dataset(countries=COUNTRIES_TO_ANALYZE, reference_year=2020, directory='wid_all_data'):
    """
    Create a dataset to analyze correlations between income and wealth inequality.
    
    Args:
        countries (list): List of country codes
        reference_year (int): Reference year for the cross-section
        directory (str): Path to WID data directory
    
    Returns:
        pd.DataFrame: Dataset with income and wealth inequality metrics
    """
    # Get cross-sectional data
    cross_section = create_cross_sectional_dataset(countries, reference_year, directory)
    
    if cross_section is None or cross_section.empty:
        print("Could not create cross-sectional dataset for correlation analysis")
        return None
    
    # Create metrics for correlation analysis
    corr_metrics = [
        ('top1_income_share', 'top1_wealth_share'),
        ('top10_income_share', 'top10_wealth_share'),
        ('bottom50_income_share', 'bottom50_wealth_share'),
        ('gdp_per_adult', 'top1_income_share'),
        ('gdp_per_adult', 'top1_wealth_share')
    ]
    
    # Calculate correlations
    correlations = {}
    
    for x_var, y_var in corr_metrics:
        if x_var in cross_section.columns and y_var in cross_section.columns:
            # Filter out NaN values
            valid_data = cross_section[[x_var, y_var]].dropna()
            
            if len(valid_data) >= 5:  # Require at least 5 countries for meaningful correlation
                corr, p_value = stats.pearsonr(valid_data[x_var], valid_data[y_var])
                correlations[f'{x_var}_vs_{y_var}'] = {
                    'correlation': corr,
                    'p_value': p_value,
                    'n': len(valid_data)
                }
    
    # Add correlations to dataset attributes
    cross_section.attrs['correlations'] = correlations
    
    return cross_section

# Main function to prepare all datasets
def prepare_all_datasets(directory='wid_all_data'):
    """
    Prepare all datasets needed for our inequality analysis.
    
    Args:
        directory (str): Path to WID data directory
    
    Returns:
        dict: Dictionary of prepared datasets
    """
    print("Preparing inequality datasets...")
    
    datasets = {}
    
    # 1. Time series of top 1% income share
    print("Creating top 1% income share time series...")
    datasets['top1_income_time'] = create_time_series_dataset(
        INCOME_VARIABLES, 'p99p100', COUNTRIES_TO_ANALYZE, directory)
    
    # 2. Time series of top 10% income share 
    print("Creating top 10% income share time series...")
    datasets['top10_income_time'] = create_time_series_dataset(
        INCOME_VARIABLES, 'p90p100', COUNTRIES_TO_ANALYZE, directory)
    
    # 3. Time series of bottom 50% income share
    print("Creating bottom 50% income share time series...")
    datasets['bottom50_income_time'] = create_time_series_dataset(
        INCOME_VARIABLES, 'p0p50', COUNTRIES_TO_ANALYZE, directory)
    
    # 4. Time series of top 1% wealth share
    print("Creating top 1% wealth share time series...")
    datasets['top1_wealth_time'] = create_time_series_dataset(
        WEALTH_VARIABLES, 'p99p100', COUNTRIES_TO_ANALYZE, directory)
    
    # 5. Try to create a dataset with share variables if available
    print("Creating share variable time series if available...")
    if SHARE_VARIABLES:
        for percentile in TOP_PERCENTILES + BOTTOM_PERCENTILES:
            dataset_name = f"share_{percentile}_time"
            datasets[dataset_name] = create_time_series_dataset(
                SHARE_VARIABLES, percentile, COUNTRIES_TO_ANALYZE, directory)
    
    # 6. Cross-sectional data for most recent year
    print("Creating cross-sectional dataset...")
    datasets['cross_section'] = create_cross_sectional_dataset(
        COUNTRIES_TO_ANALYZE, 2020, directory)
    
    # 7. Changes in income inequality (1980-2020)
    print("Creating income inequality change dataset...")
    datasets['income_change'] = create_inequality_change_dataset(
        COUNTRIES_TO_ANALYZE, INCOME_VARIABLES, 'p99p100', 1980, 2020, directory)
    
    # 8. Changes in wealth inequality (1980-2020)
    print("Creating wealth inequality change dataset...")
    datasets['wealth_change'] = create_inequality_change_dataset(
        COUNTRIES_TO_ANALYZE, WEALTH_VARIABLES, 'p99p100', 1980, 2020, directory)
    
    # 9. Correlation dataset
    print("Creating correlation dataset...")
    datasets['correlation'] = create_correlation_dataset(
        COUNTRIES_TO_ANALYZE, 2020, directory)
    
    # Save datasets to CSV files
    output_dir = 'output'
    os.makedirs(output_dir, exist_ok=True)
    
    for name, df in datasets.items():
        if df is not None and not df.empty:
            df.to_csv(os.path.join(output_dir, f'{name}.csv'), index=False)
            print(f"Saved {name}.csv")
    
    print("Dataset preparation complete!")
    return datasets

# %%
# prepared_data = prepare_all_datasets()

dataset = create_inequality_dataset(countries=['US', 'FR'], 
                                    variable_codes=INCOME_VARIABLES, 
                                    percentiles=['p99p100'], 
                                    directory='wid_all_data')
# Out:
# Trying variable code: aptincf992
#   Found data for aptincf992 for US: 58 rows
#   No data for aptincf992 with percentiles ['p99p100'] in FR
# Successfully found data for variable aptincf992

# %%
(variable_availability_df, variable_pivot_df) = compare_variable_availability(COUNTRIES_TO_ANALYZE)

# %%
variable_pivot_df[variable_pivot_df['total_countries'] == 13].head()
for var, series in variable_pivot_df.iterrows():
    if series['total_countries'] == 13:
        print(f"Variable: {var}")
# Out:
# Variable: xlcyuxi999
# Variable: eifghoi999
# Variable: wfdirxi999
# Variable: wfdipxi999
# Variable: bptincj992
# Variable: wfdinxi999
# Variable: egfcari999
# Variable: egfghgi999
# Variable: egfghoi999
# Variable: ehfcari999
# Variable: ehfghdi999
# Variable: ehfghgi999
# Variable: ehfghni999
# Variable: ehfghoi999
# Variable: eifcari999
# Variable: eifghgi999
# Variable: enfcari999
# Variable: wfinrxi999
# Variable: enfghgi999
# Variable: enfghoi999
# Variable: enncari999
# Variable: ennghgi999
# Variable: ennghoi999
# Variable: entcari999
# Variable: entcnai999
# Variable: entghgi999
# Variable: entghoi999
# Variable: entgnai999
# Variable: entonai999
# Variable: eofcari999
# Variable: eofghgi999
# Variable: eofghoi999
# Variable: wfinpxi999
# Variable: wfkanxi999
# Variable: atsopxi992
# Variable: atsxrxi992
# Variable: atsorxi992
# Variable: atsorxi999
# Variable: atstnxi992
# Variable: atstnxi999
# Variable: atstpxi992
# Variable: atstpxi999
# Variable: atstrxi992
# Variable: atstrxi999
# Variable: atsvnxi992
# Variable: atsvnxi999
# Variable: atsvpxi992
# Variable: atsvpxi999
# Variable: atsvrxi992
# Variable: atsvrxi999
# Variable: atsxrxi999
# Variable: wfkapxi999
# Variable: bdiincj992
# Variable: wgwfini999
# Variable: wgweali999
# Variable: wgwdebi999
# Variable: wgwbusi999
# Variable: bhwealj992
# Variable: wgpsgei999
# Variable: wgdproi999
# Variable: wftaxxi999
# Variable: wfsubxi999
# Variable: wflciri999
# Variable: wflcipi999
# Variable: wflcini999
# Variable: wfkarxi999
# Variable: wexpgoi999
# Variable: wenvgei999
# Variable: gdiincj992
# Variable: kofghoi999
# Variable: knfcari999
# Variable: knfghgi999
# Variable: knfghoi999
# Variable: knncari999
# Variable: knnghgi999
# Variable: knnghoi999
# Variable: kntcari999
# Variable: kntcnai999
# Variable: kntghgi999
# Variable: kntghoi999
# Variable: kntgnai999
# Variable: kntonai999
# Variable: kofcari999
# Variable: kofghgi999
# Variable: lcfghgi999
# Variable: wedugei999
# Variable: lifghgi999
# Variable: lpfcari999
# Variable: lpfghgi999
# Variable: mcitgri999
# Variable: mcomhni999
# Variable: mcomnxi999
# Variable: mcompxi999
# Variable: mcomrxi999
# Variable: mconfci999
# Variable: mcwbooi999
# Variable: mcwbusi999
# Variable: mcwdebi999
# Variable: mcwdeqi999
# Variable: mcwfini999
# Variable: kifghoi999
# Variable: kifghgi999
# Variable: kifcari999
# Variable: khfghoi999
# Variable: wedtgei999
# Variable: wedsgei999
# Variable: wedpgei999
# Variable: wecogei999
# Variable: wdefgei999
# Variable: wcwnfai999
# Variable: wcwhoui999
# Variable: ghwealj992
# Variable: wcwfini999
# Variable: wcwdeqi999
# Variable: wcwdebi999
# Variable: wcwbusi999
# Variable: wcwbooi999
# Variable: wconfci999
# Variable: wcomrxi999
# Variable: wcompxi999
# Variable: wcomnxi999
# Variable: wcomhni999
# Variable: gptincj992
# Variable: wcitgri999
# Variable: inyixxi999
# Variable: iqualii999
# Variable: kgfcari999
# Variable: kgfghgi999
# Variable: kgfghoi999
# Variable: khfcari999
# Variable: khfghdi999
# Variable: khfghgi999
# Variable: khfghni999
# Variable: atsopxi999
# Variable: atsonxi999
# Variable: aptdrxi999
# Variable: apwbusi992
# Variable: aptfxdi999
# Variable: aptfxni992
# Variable: aptfxni999
# Variable: aptincj992
# Variable: whougei999
# Variable: wheagei999
# Variable: aptrrxi992
# Variable: aptrrxi999
# Variable: aptrxai992
# Variable: aptrxai999
# Variable: aptxgoi992
# Variable: aptxgoi999
# Variable: apwagri992
# Variable: apwagri999
# Variable: apwbusi999
# Variable: aptfxai999
# Variable: apwdebi992
# Variable: apwdebi999
# Variable: apweali992
# Variable: apweali999
# Variable: apweqii992
# Variable: apweqii999
# Variable: apwfini992
# Variable: apwfini999
# Variable: apwfiwi992
# Variable: apwfiwi999
# Variable: apwhoui992
# Variable: apwhoui999
# Variable: wgwnfai999
# Variable: apwnfai992
# Variable: aptfxdi992
# Variable: aptfxai992
# Variable: atsonxi992
# Variable: aptfnxi999
# Variable: aptdxai999
# Variable: aptdxdi992
# Variable: aptdxdi999
# Variable: aptepxi992
# Variable: aptepxi999
# Variable: apterxi992
# Variable: apterxi999
# Variable: aptexai992
# Variable: aptexai999
# Variable: aptexdi992
# Variable: aptexdi999
# Variable: aptfhri992
# Variable: aptfhri999
# Variable: aptfnxi992
# Variable: aptfoni992
# Variable: aptfrxi999
# Variable: aptfoni999
# Variable: aptfopi992
# Variable: aptfopi999
# Variable: aptfori992
# Variable: aptfori999
# Variable: aptfpxi992
# Variable: aptfpxi999
# Variable: aptfrni992
# Variable: aptfrni999
# Variable: aptfrpi992
# Variable: aptfrpi999
# Variable: aptfrri992
# Variable: aptfrri999
# Variable: aptfrxi992
# Variable: apwnfai999
# Variable: apwodki992
# Variable: apwodki999
# Variable: atbmpxi992
# Variable: ascorxi999
# Variable: ascrnxi992
# Variable: ascrnxi999
# Variable: ascrpxi992
# Variable: ascrpxi999
# Variable: ascrrxi992
# Variable: ascrrxi999
# Variable: asopgei992
# Variable: asopgei999
# Variable: rdiincj992
# Variable: aspigei992
# Variable: aspigei999
# Variable: ataxnxi992
# Variable: ataxnxi999
# Variable: atbmpxi999
# Variable: wgwhoui999
# Variable: atbnnxi992
# Variable: atbnnxi999
# Variable: atbxrxi992
# Variable: atbxrxi999
# Variable: atgmpxi992
# Variable: atgmpxi999
# Variable: atgnnxi992
# Variable: atgnnxi999
# Variable: atgxrxi992
# Variable: atgxrxi999
# Variable: atsmpxi992
# Variable: atsmpxi999
# Variable: atsnnxi992
# Variable: atsnnxi999
# Variable: ascorxi992
# Variable: ascopxi999
# Variable: ascopxi992
# Variable: asconxi999
# Variable: apwpeni992
# Variable: apwpeni999
# Variable: apwtgri992
# Variable: apwtgri999
# Variable: arecgei992
# Variable: arecgei999
# Variable: aretgoi992
# Variable: aretgoi999
# Variable: arevgoi992
# Variable: arevgoi999
# Variable: asacgei992
# Variable: asacgei999
# Variable: asakgei992
# Variable: asakgei999
# Variable: ascgnxi992
# Variable: ascgnxi999
# Variable: ascgpxi992
# Variable: ascgpxi999
# Variable: ascgrxi992
# Variable: ascgrxi999
# Variable: ascinxi992
# Variable: ascinxi999
# Variable: ascipxi992
# Variable: ascipxi999
# Variable: ascirxi992
# Variable: ascirxi999
# Variable: ascogri992
# Variable: ascogri999
# Variable: asconxi992
# Variable: mcwhoui999
# Variable: mcwnfai999
# Variable: mdefgei999
# Variable: npopulf998
# Variable: npopulf751
# Variable: npopulf801
# Variable: npopulf802
# Variable: npopulf851
# Variable: npopulf901
# Variable: npopulf902
# Variable: npopulf951
# Variable: npopulf991
# Variable: npopulf992
# Variable: npopulf993
# Variable: npopulf994
# Variable: npopulf995
# Variable: npopulf996
# Variable: npopulf997
# Variable: npopulf999
# Variable: npopulf701
# Variable: npopuli001
# Variable: npopuli014
# Variable: npopuli051
# Variable: npopuli101
# Variable: npopuli111
# Variable: npopuli151
# Variable: npopuli156
# Variable: npopuli201
# Variable: npopuli202
# Variable: npopuli251
# Variable: npopuli301
# Variable: npopuli302
# Variable: npopuli351
# Variable: npopuli401
# Variable: npopulf702
# Variable: npopulf651
# Variable: mecogei999
# Variable: npopulf111
# Variable: mtsonxi999
# Variable: mtsopxi999
# Variable: mtsorxi999
# Variable: mtstnxi999
# Variable: mtstpxi999
# Variable: mtstrxi999
# Variable: mtsvnxi999
# Variable: mtsvpxi999
# Variable: mtsvrxi999
# Variable: mtsxrxi999
# Variable: npopulf001
# Variable: npopulf014
# Variable: npopulf051
# Variable: npopulf101
# Variable: npopulf151
# Variable: npopulf602
# Variable: npopulf156
# Variable: npopulf201
# Variable: npopulf202
# Variable: npopulf251
# Variable: npopulf301
# Variable: npopulf302
# Variable: npopulf351
# Variable: npopulf401
# Variable: npopulf402
# Variable: npopulf451
# Variable: npopulf501
# Variable: npopulf502
# Variable: npopulf551
# Variable: npopulf601
# Variable: npopuli402
# Variable: npopuli451
# Variable: npopuli501
# Variable: npopulm801
# Variable: npopulm302
# Variable: npopulm351
# Variable: npopulm401
# Variable: npopulm402
# Variable: npopulm451
# Variable: npopulm501
# Variable: npopulm502
# Variable: npopulm551
# Variable: npopulm601
# Variable: npopulm602
# Variable: npopulm651
# Variable: npopulm701
# Variable: npopulm702
# Variable: npopulm751
# Variable: npopulm802
# Variable: npopuli502
# Variable: npopulm851
# Variable: npopulm901
# Variable: npopulm902
# Variable: npopulm951
# Variable: npopulm991
# Variable: npopulm992
# Variable: npopulm993
# Variable: npopulm994
# Variable: npopulm995
# Variable: npopulm996
# Variable: npopulm997
# Variable: npopulm998
# Variable: npopulm999
# Variable: rptincj992
# Variable: npopulm301
# Variable: npopulm251
# Variable: npopulm202
# Variable: npopulm201
# Variable: npopuli551
# Variable: npopuli601
# Variable: npopuli602
# Variable: npopuli651
# Variable: npopuli701
# Variable: npopuli702
# Variable: npopuli751
# Variable: npopuli801
# Variable: npopuli802
# Variable: npopuli851
# Variable: npopuli901
# Variable: npopuli902
# Variable: npopuli951
# Variable: npopuli991
# Variable: npopuli992
# Variable: npopuli993
# Variable: npopuli994
# Variable: npopuli995
# Variable: npopuli996
# Variable: npopuli997
# Variable: npopuli998
# Variable: npopuli999
# Variable: npopulm001
# Variable: npopulm014
# Variable: npopulm051
# Variable: npopulm101
# Variable: npopulm111
# Variable: npopulm151
# Variable: npopulm156
# Variable: mtsnnxi999
# Variable: mtsmpxi999
# Variable: mtgxrxi999
# Variable: mntrgri999
# Variable: mheagei999
# Variable: mhougei999
# Variable: mhweali999
# Variable: tdiincj992
# Variable: minpgoi999
# Variable: mintgri999
# Variable: miweali999
# Variable: sptincj992
# Variable: spllinf992
# Variable: shwealj992
# Variable: mncanxi999
# Variable: mndproi999
# Variable: mnnfini999
# Variable: mnninci999
# Variable: mnwagri999
# Variable: mpinrxi999
# Variable: mnwbooi999
# Variable: mnwbusi999
# Variable: mnweali999
# Variable: mnwgxai999
# Variable: mnwgxdi999
# Variable: mnwhoui999
# Variable: mnwnfai999
# Variable: mnwnxai999
# Variable: mnwoffi999
# Variable: mopinxi999
# Variable: mopipxi999
# Variable: mopirxi999
# Variable: mottgri999
# Variable: mpinnxi999
# Variable: mgwnfai999
# Variable: mgwhoui999
# Variable: mgwfini999
# Variable: mgweali999
# Variable: medpgei999
# Variable: medsgei999
# Variable: medtgei999
# Variable: medugei999
# Variable: menvgei999
# Variable: mexpgoi999
# Variable: mfdinxi999
# Variable: mfdipxi999
# Variable: mfdirxi999
# Variable: mfdixai999
# Variable: mfdixdi999
# Variable: mfdixni999
# Variable: mfinpxi999
# Variable: mfinrxi999
# Variable: mfkanxi999
# Variable: mfkapxi999
# Variable: mfkarxi999
# Variable: mflcini999
# Variable: mflcipi999
# Variable: mflciri999
# Variable: tptincj992
# Variable: thwealj992
# Variable: mfsubxi999
# Variable: mftaxxi999
# Variable: mgdproi999
# Variable: mgninci999
# Variable: mgpsgei999
# Variable: mgwbusi999
# Variable: mgwdebi999
# Variable: mpinpxi999
# Variable: mpitgri999
# Variable: mtgnnxi999
# Variable: mscipxi999
# Variable: mpwnfai999
# Variable: mpwodki999
# Variable: sdiincj992
# Variable: mpwpeni999
# Variable: mpwtgri999
# Variable: mrecgei999
# Variable: mretgoi999
# Variable: mrevgoi999
# Variable: msacgei999
# Variable: msakgei999
# Variable: mscgnxi999
# Variable: mscgpxi999
# Variable: mscgrxi999
# Variable: mscinxi999
# Variable: mscirxi999
# Variable: mpolgei999
# Variable: mscogri999
# Variable: msconxi999
# Variable: mscopxi999
# Variable: mscorxi999
# Variable: mscrnxi999
# Variable: mscrpxi999
# Variable: mscrrxi999
# Variable: msopgei999
# Variable: mspigei999
# Variable: mtaxnxi999
# Variable: mtbmpxi999
# Variable: mtbnnxi999
# Variable: mtbxrxi999
# Variable: mtgmpxi999
# Variable: mpwhoui999
# Variable: mpwfiwi999
# Variable: mpwfini999
# Variable: mpweqii999
# Variable: mpsugoi999
# Variable: mptdpxi999
# Variable: mptdrxi999
# Variable: mptdxai999
# Variable: mptdxdi999
# Variable: mptepxi999
# Variable: mpterxi999
# Variable: mptexai999
# Variable: mptexdi999
# Variable: mptfhri999
# Variable: mptfnxi999
# Variable: mptfoni999
# Variable: mptfopi999
# Variable: mptfori999
# Variable: mptfpxi999
# Variable: mptfrni999
# Variable: mptfrpi999
# Variable: mptfrri999
# Variable: mptfrxi999
# Variable: mptfxai999
# Variable: mptfxdi999
# Variable: mptfxni999
# Variable: mptrrxi999
# Variable: mptrxai999
# Variable: mptxgoi999
# Variable: mpwagri999
# Variable: mpwbusi999
# Variable: mpwdebi999
# Variable: mpweali999
# Variable: aptdxai992
# Variable: rhwealj992
# Variable: aptdrxi992
# Variable: aenvgei999
# Variable: wspigei999
# Variable: wtaxnxi999
# Variable: wtbmpxi999
# Variable: wtbnnxi999
# Variable: wtbxrxi999
# Variable: aexpgoi999
# Variable: aexpgoi992
# Variable: aenvgei992
# Variable: agwnfai999
# Variable: aedugei999
# Variable: aedugei992
# Variable: aedtgei999
# Variable: aedtgei992
# Variable: aedsgei999
# Variable: aedsgei992
# Variable: aedpgei999
# Variable: wsopgei999
# Variable: wscogri999
# Variable: wscirxi999
# Variable: wncanxi999
# Variable: aheagei999
# Variable: ahougei992
# Variable: ahougei999
# Variable: afdinxi992
# Variable: wscipxi999
# Variable: wnwgxai999
# Variable: wnweali999
# Variable: wnwbusi999
# Variable: wnwbooi999
# Variable: ahweali992
# Variable: wnwagri999
# Variable: ahweali999
# Variable: ahwealj992
# Variable: wnnfini999
# Variable: wndproi999
# Variable: aedpgei992
# Variable: ainpgoi992
# Variable: ainpgoi999
# Variable: xlceuxi999
# Variable: xlcusxi999
# Variable: xlcyupi999
# Variable: wintgri999
# Variable: ancanxi992
# Variable: ancanxi999
# Variable: andproi992
# Variable: andproi999
# Variable: annfini992
# Variable: annfini999
# Variable: anninci992
# Variable: anninci999
# Variable: antrgri992
# Variable: antrgri999
# Variable: aconfci999
# Variable: aconfci992
# Variable: xlcuspi999
# Variable: xlceupi999
# Variable: aintgri992
# Variable: wwealpi999
# Variable: aintgri999
# Variable: wiweali999
# Variable: aecogei999
# Variable: aecogei992
# Variable: wtgmpxi999
# Variable: wtgnnxi999
# Variable: wtgxrxi999
# Variable: adiincj992
# Variable: wtsnnxi999
# Variable: wtsxrxi999
# Variable: wwealgi999
# Variable: wwealhi999
# Variable: wwealni999
# Variable: adefgei999
# Variable: adefgei992
# Variable: aheagei992
# Variable: agwnfai992
# Variable: acomrxi992
# Variable: afkarxi992
# Variable: agdproi992
# Variable: agdproi999
# Variable: agninci992
# Variable: agninci999
# Variable: agpsgei992
# Variable: agpsgei999
# Variable: afkarxi999
# Variable: afkapxi999
# Variable: wnwgxdi999
# Variable: afkapxi992
# Variable: afkanxi999
# Variable: afkanxi992
# Variable: wptfpxi999
# Variable: wptfrxi999
# Variable: wpwagri999
# Variable: afinrxi999
# Variable: aflcini992
# Variable: aflcini999
# Variable: aftaxxi999
# Variable: aflcipi992
# Variable: aflciri999
# Variable: wptfnxi999
# Variable: wpolgei999
# Variable: wpitgri999
# Variable: wpinrxi999
# Variable: wpinpxi999
# Variable: wpinnxi999
# Variable: wottgri999
# Variable: wnwnxai999
# Variable: wnwnfai999
# Variable: aflciri992
# Variable: aflcipi999
# Variable: afsubxi992
# Variable: afsubxi999
# Variable: aftaxxi992
# Variable: afinrxi992
# Variable: afinpxi999
# Variable: afinpxi992
# Variable: wsakgei999
# Variable: afdixni999
# Variable: afdixni992
# Variable: afdixdi999
# Variable: agwfini992
# Variable: afdixdi992
# Variable: afdixai999
# Variable: afdixai992
# Variable: afdirxi999
# Variable: agwfini999
# Variable: aptdpxi999
# Variable: afdirxi992
# Variable: afdipxi999
# Variable: afdipxi992
# Variable: afdinxi999
# Variable: wnwhoui999
# Variable: wscinxi999
# Variable: agweali999
# Variable: wpwbusi999
# Variable: agweali992
# Variable: wpwdebi999
# Variable: wpweali999
# Variable: wpweqii999
# Variable: wpwfini999
# Variable: wpwfiwi999
# Variable: wpwhoui999
# Variable: wpwnfai999
# Variable: wpwodki999
# Variable: wpwpeni999
# Variable: wpwtgri999
# Variable: wrecgei999
# Variable: wrevgoi999
# Variable: wsacgei999
# Variable: agwdebi992
# Variable: agwdebi999
# Variable: acomrxi999
# Variable: wtsmpxi999
# Variable: acompxi999
# Variable: acitgri999
# Variable: anwoffi992
# Variable: acitgri992
# Variable: acompxi992
# Variable: apinpxi992
# Variable: apinpxi999
# Variable: anweali999
# Variable: apinrxi992
# Variable: apinrxi999
# Variable: apitgri992
# Variable: acomhni992
# Variable: anwnxai999
# Variable: anwnxai992
# Variable: anwnfai999
# Variable: anwnfai992
# Variable: apitgri999
# Variable: acomnxi999
# Variable: anwgxdi999
# Variable: apolgei992
# Variable: anwgxdi992
# Variable: anwgxai999
# Variable: anwgxai992
# Variable: acomnxi992
# Variable: apolgei999
# Variable: anwoffi999
# Variable: acomhni999
# Variable: aopirxi992
# Variable: apsugoi999
# Variable: aopinxi992
# Variable: aopipxi999
# Variable: aopipxi992
# Variable: aopirxi999
# Variable: anweali992
# Variable: aottgri992
# Variable: aptdpxi992
# Variable: aopinxi999
# Variable: aottgri999
# Variable: apsugoi992
# Variable: apinnxi999
# Variable: whweali999
# Variable: apinnxi992

# %%
# Print variables that are present for every country
for var, series in variable_availability_df.iterrows():
    # print(var)
    if all(series):
        print(f"Variable {var} is available for all countries.")
    else:
        continue
        # print(f"Variable {var} is not available for all countries.")
# Out:
# Variable 0 is available for all countries.
# Variable 1 is available for all countries.
# Variable 2 is available for all countries.
# Variable 3 is available for all countries.
# Variable 4 is available for all countries.
# Variable 5 is available for all countries.
# Variable 6 is available for all countries.
# Variable 7 is available for all countries.
# Variable 8 is available for all countries.
# Variable 9 is available for all countries.
# Variable 10 is available for all countries.
# Variable 11 is available for all countries.
# Variable 12 is available for all countries.
# Variable 13 is available for all countries.
# Variable 14 is available for all countries.
# Variable 15 is available for all countries.
# Variable 16 is available for all countries.
# Variable 17 is available for all countries.
# Variable 18 is available for all countries.
# Variable 19 is available for all countries.
# Variable 20 is available for all countries.
# Variable 21 is available for all countries.
# Variable 22 is available for all countries.
# Variable 23 is available for all countries.
# Variable 24 is available for all countries.
# Variable 25 is available for all countries.
# Variable 26 is available for all countries.
# Variable 27 is available for all countries.
# Variable 28 is available for all countries.
# Variable 29 is available for all countries.
# Variable 30 is available for all countries.
# Variable 31 is available for all countries.
# Variable 32 is available for all countries.
# Variable 33 is available for all countries.
# Variable 34 is available for all countries.
# Variable 35 is available for all countries.
# Variable 36 is available for all countries.
# Variable 37 is available for all countries.
# Variable 38 is available for all countries.
# Variable 39 is available for all countries.
# Variable 40 is available for all countries.
# Variable 41 is available for all countries.
# Variable 42 is available for all countries.
# Variable 43 is available for all countries.
# Variable 44 is available for all countries.
# Variable 45 is available for all countries.
# Variable 46 is available for all countries.
# Variable 47 is available for all countries.
# Variable 48 is available for all countries.
# Variable 49 is available for all countries.
# Variable 50 is available for all countries.
# Variable 51 is available for all countries.
# Variable 52 is available for all countries.
# Variable 53 is available for all countries.
# Variable 54 is available for all countries.
# Variable 55 is available for all countries.
# Variable 56 is available for all countries.
# Variable 57 is available for all countries.
# Variable 58 is available for all countries.
# Variable 59 is available for all countries.
# Variable 60 is available for all countries.
# Variable 61 is available for all countries.
# Variable 62 is available for all countries.
# Variable 63 is available for all countries.
# Variable 64 is available for all countries.
# Variable 65 is available for all countries.
# Variable 66 is available for all countries.
# Variable 67 is available for all countries.
# Variable 68 is available for all countries.
# Variable 69 is available for all countries.
# Variable 70 is available for all countries.
# Variable 71 is available for all countries.
# Variable 72 is available for all countries.
# Variable 73 is available for all countries.
# Variable 74 is available for all countries.
# Variable 75 is available for all countries.
# Variable 76 is available for all countries.
# Variable 77 is available for all countries.
# Variable 78 is available for all countries.
# Variable 79 is available for all countries.
# Variable 80 is available for all countries.
# Variable 81 is available for all countries.
# Variable 82 is available for all countries.
# Variable 83 is available for all countries.
# Variable 84 is available for all countries.
# Variable 85 is available for all countries.
# Variable 86 is available for all countries.
# Variable 87 is available for all countries.
# Variable 88 is available for all countries.
# Variable 89 is available for all countries.
# Variable 90 is available for all countries.
# Variable 91 is available for all countries.
# Variable 92 is available for all countries.
# Variable 93 is available for all countries.
# Variable 94 is available for all countries.
# Variable 95 is available for all countries.
# Variable 96 is available for all countries.
# Variable 97 is available for all countries.
# Variable 98 is available for all countries.
# Variable 99 is available for all countries.
# Variable 100 is available for all countries.
# Variable 101 is available for all countries.
# Variable 102 is available for all countries.
# Variable 103 is available for all countries.
# Variable 104 is available for all countries.
# Variable 105 is available for all countries.
# Variable 106 is available for all countries.
# Variable 107 is available for all countries.
# Variable 108 is available for all countries.
# Variable 109 is available for all countries.
# Variable 110 is available for all countries.
# Variable 111 is available for all countries.
# Variable 112 is available for all countries.
# Variable 113 is available for all countries.
# Variable 114 is available for all countries.
# Variable 115 is available for all countries.
# Variable 116 is available for all countries.
# Variable 117 is available for all countries.
# Variable 118 is available for all countries.
# Variable 119 is available for all countries.
# Variable 120 is available for all countries.
# Variable 121 is available for all countries.
# Variable 122 is available for all countries.
# Variable 123 is available for all countries.
# Variable 124 is available for all countries.
# Variable 125 is available for all countries.
# Variable 126 is available for all countries.
# Variable 127 is available for all countries.
# Variable 128 is available for all countries.
# Variable 129 is available for all countries.
# Variable 130 is available for all countries.
# Variable 131 is available for all countries.
# Variable 132 is available for all countries.
# Variable 133 is available for all countries.
# Variable 134 is available for all countries.
# Variable 135 is available for all countries.
# Variable 136 is available for all countries.
# Variable 137 is available for all countries.
# Variable 138 is available for all countries.
# Variable 139 is available for all countries.
# Variable 140 is available for all countries.
# Variable 141 is available for all countries.
# Variable 142 is available for all countries.
# Variable 143 is available for all countries.
# Variable 144 is available for all countries.
# Variable 145 is available for all countries.
# Variable 146 is available for all countries.
# Variable 147 is available for all countries.
# Variable 148 is available for all countries.
# Variable 149 is available for all countries.
# Variable 150 is available for all countries.
# Variable 151 is available for all countries.
# Variable 152 is available for all countries.
# Variable 153 is available for all countries.
# Variable 154 is available for all countries.
# Variable 155 is available for all countries.
# Variable 156 is available for all countries.
# Variable 157 is available for all countries.
# Variable 158 is available for all countries.
# Variable 159 is available for all countries.
# Variable 160 is available for all countries.
# Variable 161 is available for all countries.
# Variable 162 is available for all countries.
# Variable 163 is available for all countries.
# Variable 164 is available for all countries.
# Variable 165 is available for all countries.
# Variable 166 is available for all countries.
# Variable 167 is available for all countries.
# Variable 168 is available for all countries.
# Variable 169 is available for all countries.
# Variable 170 is available for all countries.
# Variable 171 is available for all countries.
# Variable 172 is available for all countries.
# Variable 173 is available for all countries.
# Variable 174 is available for all countries.
# Variable 175 is available for all countries.
# Variable 176 is available for all countries.
# Variable 177 is available for all countries.
# Variable 178 is available for all countries.
# Variable 179 is available for all countries.
# Variable 180 is available for all countries.
# Variable 181 is available for all countries.
# Variable 182 is available for all countries.
# Variable 183 is available for all countries.
# Variable 184 is available for all countries.
# Variable 185 is available for all countries.
# Variable 186 is available for all countries.
# Variable 187 is available for all countries.
# Variable 188 is available for all countries.
# Variable 189 is available for all countries.
# Variable 190 is available for all countries.
# Variable 191 is available for all countries.
# Variable 192 is available for all countries.
# Variable 193 is available for all countries.
# Variable 194 is available for all countries.
# Variable 195 is available for all countries.
# Variable 196 is available for all countries.
# Variable 197 is available for all countries.
# Variable 198 is available for all countries.
# Variable 199 is available for all countries.
# Variable 200 is available for all countries.
# Variable 201 is available for all countries.
# Variable 202 is available for all countries.
# Variable 203 is available for all countries.
# Variable 204 is available for all countries.
# Variable 205 is available for all countries.
# Variable 206 is available for all countries.
# Variable 207 is available for all countries.
# Variable 208 is available for all countries.
# Variable 209 is available for all countries.
# Variable 210 is available for all countries.
# Variable 211 is available for all countries.
# Variable 212 is available for all countries.
# Variable 213 is available for all countries.
# Variable 214 is available for all countries.
# Variable 215 is available for all countries.
# Variable 216 is available for all countries.
# Variable 217 is available for all countries.
# Variable 218 is available for all countries.
# Variable 219 is available for all countries.
# Variable 220 is available for all countries.
# Variable 221 is available for all countries.
# Variable 222 is available for all countries.
# Variable 223 is available for all countries.
# Variable 224 is available for all countries.
# Variable 225 is available for all countries.
# Variable 226 is available for all countries.
# Variable 227 is available for all countries.
# Variable 228 is available for all countries.
# Variable 229 is available for all countries.
# Variable 230 is available for all countries.
# Variable 231 is available for all countries.
# Variable 232 is available for all countries.
# Variable 233 is available for all countries.
# Variable 234 is available for all countries.
# Variable 235 is available for all countries.
# Variable 236 is available for all countries.
# Variable 237 is available for all countries.
# Variable 238 is available for all countries.
# Variable 239 is available for all countries.
# Variable 240 is available for all countries.
# Variable 241 is available for all countries.
# Variable 242 is available for all countries.
# Variable 243 is available for all countries.
# Variable 244 is available for all countries.
# Variable 245 is available for all countries.
# Variable 246 is available for all countries.
# Variable 247 is available for all countries.
# Variable 248 is available for all countries.
# Variable 249 is available for all countries.
# Variable 250 is available for all countries.
# Variable 251 is available for all countries.
# Variable 252 is available for all countries.
# Variable 253 is available for all countries.
# Variable 254 is available for all countries.
# Variable 255 is available for all countries.
# Variable 256 is available for all countries.
# Variable 257 is available for all countries.
# Variable 258 is available for all countries.
# Variable 259 is available for all countries.
# Variable 260 is available for all countries.
# Variable 261 is available for all countries.
# Variable 262 is available for all countries.
# Variable 263 is available for all countries.
# Variable 264 is available for all countries.
# Variable 265 is available for all countries.
# Variable 266 is available for all countries.
# Variable 267 is available for all countries.
# Variable 268 is available for all countries.
# Variable 269 is available for all countries.
# Variable 270 is available for all countries.
# Variable 271 is available for all countries.
# Variable 272 is available for all countries.
# Variable 273 is available for all countries.
# Variable 274 is available for all countries.
# Variable 275 is available for all countries.
# Variable 276 is available for all countries.
# Variable 277 is available for all countries.
# Variable 278 is available for all countries.
# Variable 279 is available for all countries.
# Variable 280 is available for all countries.
# Variable 281 is available for all countries.
# Variable 282 is available for all countries.
# Variable 283 is available for all countries.
# Variable 284 is available for all countries.
# Variable 285 is available for all countries.
# Variable 286 is available for all countries.
# Variable 287 is available for all countries.
# Variable 288 is available for all countries.
# Variable 289 is available for all countries.
# Variable 290 is available for all countries.
# Variable 291 is available for all countries.
# Variable 292 is available for all countries.
# Variable 293 is available for all countries.
# Variable 294 is available for all countries.
# Variable 295 is available for all countries.
# Variable 296 is available for all countries.
# Variable 297 is available for all countries.
# Variable 298 is available for all countries.
# Variable 299 is available for all countries.
# Variable 300 is available for all countries.
# Variable 301 is available for all countries.
# Variable 302 is available for all countries.
# Variable 303 is available for all countries.
# Variable 304 is available for all countries.
# Variable 305 is available for all countries.
# Variable 306 is available for all countries.
# Variable 307 is available for all countries.
# Variable 308 is available for all countries.
# Variable 309 is available for all countries.
# Variable 310 is available for all countries.
# Variable 311 is available for all countries.
# Variable 312 is available for all countries.
# Variable 313 is available for all countries.
# Variable 314 is available for all countries.
# Variable 315 is available for all countries.
# Variable 316 is available for all countries.
# Variable 317 is available for all countries.
# Variable 318 is available for all countries.
# Variable 319 is available for all countries.
# Variable 320 is available for all countries.
# Variable 321 is available for all countries.
# Variable 322 is available for all countries.
# Variable 323 is available for all countries.
# Variable 324 is available for all countries.
# Variable 325 is available for all countries.
# Variable 326 is available for all countries.
# Variable 327 is available for all countries.
# Variable 328 is available for all countries.
# Variable 329 is available for all countries.
# Variable 330 is available for all countries.
# Variable 331 is available for all countries.
# Variable 332 is available for all countries.
# Variable 333 is available for all countries.
# Variable 334 is available for all countries.
# Variable 335 is available for all countries.
# Variable 336 is available for all countries.
# Variable 337 is available for all countries.
# Variable 338 is available for all countries.
# Variable 339 is available for all countries.
# Variable 340 is available for all countries.
# Variable 341 is available for all countries.
# Variable 342 is available for all countries.
# Variable 343 is available for all countries.
# Variable 344 is available for all countries.
# Variable 345 is available for all countries.
# Variable 346 is available for all countries.
# Variable 347 is available for all countries.
# Variable 348 is available for all countries.
# Variable 349 is available for all countries.
# Variable 350 is available for all countries.
# Variable 351 is available for all countries.
# Variable 352 is available for all countries.
# Variable 353 is available for all countries.
# Variable 354 is available for all countries.
# Variable 355 is available for all countries.
# Variable 356 is available for all countries.
# Variable 357 is available for all countries.
# Variable 358 is available for all countries.
# Variable 359 is available for all countries.
# Variable 360 is available for all countries.
# Variable 361 is available for all countries.
# Variable 362 is available for all countries.
# Variable 363 is available for all countries.
# Variable 364 is available for all countries.
# Variable 365 is available for all countries.
# Variable 366 is available for all countries.
# Variable 367 is available for all countries.
# Variable 368 is available for all countries.
# Variable 369 is available for all countries.
# Variable 370 is available for all countries.
# Variable 371 is available for all countries.
# Variable 372 is available for all countries.
# Variable 373 is available for all countries.
# Variable 374 is available for all countries.
# Variable 375 is available for all countries.
# Variable 376 is available for all countries.
# Variable 377 is available for all countries.
# Variable 378 is available for all countries.
# Variable 379 is available for all countries.
# Variable 380 is available for all countries.
# Variable 381 is available for all countries.
# Variable 382 is available for all countries.
# Variable 383 is available for all countries.
# Variable 384 is available for all countries.
# Variable 385 is available for all countries.
# Variable 386 is available for all countries.
# Variable 387 is available for all countries.
# Variable 388 is available for all countries.
# Variable 389 is available for all countries.
# Variable 390 is available for all countries.
# Variable 391 is available for all countries.
# Variable 392 is available for all countries.
# Variable 393 is available for all countries.
# Variable 394 is available for all countries.
# Variable 395 is available for all countries.
# Variable 396 is available for all countries.
# Variable 397 is available for all countries.
# Variable 398 is available for all countries.
# Variable 399 is available for all countries.
# Variable 400 is available for all countries.
# Variable 401 is available for all countries.
# Variable 402 is available for all countries.
# Variable 403 is available for all countries.
# Variable 404 is available for all countries.
# Variable 405 is available for all countries.
# Variable 406 is available for all countries.
# Variable 407 is available for all countries.
# Variable 408 is available for all countries.
# Variable 409 is available for all countries.
# Variable 410 is available for all countries.
# Variable 411 is available for all countries.
# Variable 412 is available for all countries.
# Variable 413 is available for all countries.
# Variable 414 is available for all countries.
# Variable 415 is available for all countries.
# Variable 416 is available for all countries.
# Variable 417 is available for all countries.
# Variable 418 is available for all countries.
# Variable 419 is available for all countries.
# Variable 420 is available for all countries.
# Variable 421 is available for all countries.
# Variable 422 is available for all countries.
# Variable 423 is available for all countries.
# Variable 424 is available for all countries.
# Variable 425 is available for all countries.
# Variable 426 is available for all countries.
# Variable 427 is available for all countries.
# Variable 428 is available for all countries.
# Variable 429 is available for all countries.
# Variable 430 is available for all countries.
# Variable 431 is available for all countries.
# Variable 432 is available for all countries.
# Variable 433 is available for all countries.
# Variable 434 is available for all countries.
# Variable 435 is available for all countries.
# Variable 436 is available for all countries.
# Variable 437 is available for all countries.
# Variable 438 is available for all countries.
# Variable 439 is available for all countries.
# Variable 440 is available for all countries.
# Variable 441 is available for all countries.
# Variable 442 is available for all countries.
# Variable 443 is available for all countries.
# Variable 444 is available for all countries.
# Variable 445 is available for all countries.
# Variable 446 is available for all countries.
# Variable 447 is available for all countries.
# Variable 448 is available for all countries.
# Variable 449 is available for all countries.
# Variable 450 is available for all countries.
# Variable 451 is available for all countries.
# Variable 452 is available for all countries.
# Variable 453 is available for all countries.
# Variable 454 is available for all countries.
# Variable 455 is available for all countries.
# Variable 456 is available for all countries.
# Variable 457 is available for all countries.
# Variable 458 is available for all countries.
# Variable 459 is available for all countries.
# Variable 460 is available for all countries.
# Variable 461 is available for all countries.
# Variable 462 is available for all countries.
# Variable 463 is available for all countries.
# Variable 464 is available for all countries.
# Variable 465 is available for all countries.
# Variable 466 is available for all countries.
# Variable 467 is available for all countries.
# Variable 468 is available for all countries.
# Variable 469 is available for all countries.
# Variable 470 is available for all countries.
# Variable 471 is available for all countries.
# Variable 472 is available for all countries.
# Variable 473 is available for all countries.
# Variable 474 is available for all countries.
# Variable 475 is available for all countries.
# Variable 476 is available for all countries.
# Variable 477 is available for all countries.
# Variable 478 is available for all countries.
# Variable 479 is available for all countries.
# Variable 480 is available for all countries.
# Variable 481 is available for all countries.
# Variable 482 is available for all countries.
# Variable 483 is available for all countries.
# Variable 484 is available for all countries.
# Variable 485 is available for all countries.
# Variable 486 is available for all countries.
# Variable 487 is available for all countries.
# Variable 488 is available for all countries.
# Variable 489 is available for all countries.
# Variable 490 is available for all countries.
# Variable 491 is available for all countries.
# Variable 492 is available for all countries.
# Variable 493 is available for all countries.
# Variable 494 is available for all countries.
# Variable 495 is available for all countries.
# Variable 496 is available for all countries.
# Variable 497 is available for all countries.
# Variable 498 is available for all countries.
# Variable 499 is available for all countries.
# Variable 500 is available for all countries.
# Variable 501 is available for all countries.
# Variable 502 is available for all countries.
# Variable 503 is available for all countries.
# Variable 504 is available for all countries.
# Variable 505 is available for all countries.
# Variable 506 is available for all countries.
# Variable 507 is available for all countries.
# Variable 508 is available for all countries.
# Variable 509 is available for all countries.
# Variable 510 is available for all countries.
# Variable 511 is available for all countries.
# Variable 512 is available for all countries.
# Variable 513 is available for all countries.
# Variable 514 is available for all countries.
# Variable 515 is available for all countries.
# Variable 516 is available for all countries.
# Variable 517 is available for all countries.
# Variable 518 is available for all countries.
# Variable 519 is available for all countries.
# Variable 520 is available for all countries.
# Variable 521 is available for all countries.
# Variable 522 is available for all countries.
# Variable 523 is available for all countries.
# Variable 524 is available for all countries.
# Variable 525 is available for all countries.
# Variable 526 is available for all countries.
# Variable 527 is available for all countries.
# Variable 528 is available for all countries.
# Variable 529 is available for all countries.
# Variable 530 is available for all countries.
# Variable 531 is available for all countries.
# Variable 532 is available for all countries.
# Variable 533 is available for all countries.
# Variable 534 is available for all countries.
# Variable 535 is available for all countries.
# Variable 536 is available for all countries.
# Variable 537 is available for all countries.
# Variable 538 is available for all countries.
# Variable 539 is available for all countries.
# Variable 540 is available for all countries.
# Variable 541 is available for all countries.
# Variable 542 is available for all countries.
# Variable 543 is available for all countries.
# Variable 544 is available for all countries.
# Variable 545 is available for all countries.
# Variable 546 is available for all countries.
# Variable 547 is available for all countries.
# Variable 548 is available for all countries.
# Variable 549 is available for all countries.
# Variable 550 is available for all countries.
# Variable 551 is available for all countries.
# Variable 552 is available for all countries.
# Variable 553 is available for all countries.
# Variable 554 is available for all countries.
# Variable 555 is available for all countries.
# Variable 556 is available for all countries.
# Variable 557 is available for all countries.
# Variable 558 is available for all countries.
# Variable 559 is available for all countries.
# Variable 560 is available for all countries.
# Variable 561 is available for all countries.
# Variable 562 is available for all countries.
# Variable 563 is available for all countries.
# Variable 564 is available for all countries.
# Variable 565 is available for all countries.
# Variable 566 is available for all countries.
# Variable 567 is available for all countries.
# Variable 568 is available for all countries.
# Variable 569 is available for all countries.
# Variable 570 is available for all countries.
# Variable 571 is available for all countries.
# Variable 572 is available for all countries.
# Variable 573 is available for all countries.
# Variable 574 is available for all countries.
# Variable 575 is available for all countries.
# Variable 576 is available for all countries.
# Variable 577 is available for all countries.
# Variable 578 is available for all countries.
# Variable 579 is available for all countries.
# Variable 580 is available for all countries.
# Variable 581 is available for all countries.
# Variable 582 is available for all countries.
# Variable 583 is available for all countries.
# Variable 584 is available for all countries.
# Variable 585 is available for all countries.
# Variable 586 is available for all countries.
# Variable 587 is available for all countries.
# Variable 588 is available for all countries.
# Variable 589 is available for all countries.
# Variable 590 is available for all countries.
# Variable 591 is available for all countries.
# Variable 592 is available for all countries.
# Variable 593 is available for all countries.
# Variable 594 is available for all countries.
# Variable 595 is available for all countries.
# Variable 596 is available for all countries.
# Variable 597 is available for all countries.
# Variable 598 is available for all countries.
# Variable 599 is available for all countries.
# Variable 600 is available for all countries.
# Variable 601 is available for all countries.
# Variable 602 is available for all countries.
# Variable 603 is available for all countries.
# Variable 604 is available for all countries.
# Variable 605 is available for all countries.
# Variable 606 is available for all countries.
# Variable 607 is available for all countries.
# Variable 608 is available for all countries.
# Variable 609 is available for all countries.
# Variable 610 is available for all countries.
# Variable 611 is available for all countries.
# Variable 612 is available for all countries.
# Variable 613 is available for all countries.
# Variable 614 is available for all countries.
# Variable 615 is available for all countries.
# Variable 616 is available for all countries.
# Variable 617 is available for all countries.
# Variable 618 is available for all countries.
# Variable 619 is available for all countries.
# Variable 620 is available for all countries.
# Variable 621 is available for all countries.
# Variable 622 is available for all countries.
# Variable 623 is available for all countries.
# Variable 624 is available for all countries.
# Variable 625 is available for all countries.
# Variable 626 is available for all countries.
# Variable 627 is available for all countries.
# Variable 628 is available for all countries.
# Variable 629 is available for all countries.
# Variable 630 is available for all countries.
# Variable 631 is available for all countries.
# Variable 632 is available for all countries.
# Variable 633 is available for all countries.
# Variable 634 is available for all countries.
# Variable 635 is available for all countries.
# Variable 636 is available for all countries.
# Variable 637 is available for all countries.
# Variable 638 is available for all countries.
# Variable 639 is available for all countries.
# Variable 640 is available for all countries.
# Variable 641 is available for all countries.
# Variable 642 is available for all countries.
# Variable 643 is available for all countries.
# Variable 644 is available for all countries.
# Variable 645 is available for all countries.
# Variable 646 is available for all countries.
# Variable 647 is available for all countries.
# Variable 648 is available for all countries.
# Variable 649 is available for all countries.
# Variable 650 is available for all countries.
# Variable 651 is available for all countries.
# Variable 652 is available for all countries.
# Variable 653 is available for all countries.
# Variable 654 is available for all countries.
# Variable 655 is available for all countries.
# Variable 656 is available for all countries.
# Variable 657 is available for all countries.
# Variable 658 is available for all countries.
# Variable 659 is available for all countries.
# Variable 660 is available for all countries.
# Variable 661 is available for all countries.
# Variable 662 is available for all countries.
# Variable 663 is available for all countries.
# Variable 664 is available for all countries.
# Variable 665 is available for all countries.
# Variable 666 is available for all countries.
# Variable 667 is available for all countries.
# Variable 668 is available for all countries.
# Variable 669 is available for all countries.
# Variable 670 is available for all countries.
# Variable 671 is available for all countries.
# Variable 672 is available for all countries.
# Variable 673 is available for all countries.
# Variable 674 is available for all countries.
# Variable 675 is available for all countries.
# Variable 676 is available for all countries.
# Variable 677 is available for all countries.
# Variable 678 is available for all countries.
# Variable 679 is available for all countries.
# Variable 680 is available for all countries.
# Variable 681 is available for all countries.
# Variable 682 is available for all countries.
# Variable 683 is available for all countries.
# Variable 684 is available for all countries.
# Variable 685 is available for all countries.
# Variable 686 is available for all countries.
# Variable 687 is available for all countries.
# Variable 688 is available for all countries.
# Variable 689 is available for all countries.
# Variable 690 is available for all countries.
# Variable 691 is available for all countries.
# Variable 692 is available for all countries.
# Variable 693 is available for all countries.
# Variable 694 is available for all countries.
# Variable 695 is available for all countries.
# Variable 696 is available for all countries.
# Variable 697 is available for all countries.
# Variable 698 is available for all countries.
# Variable 699 is available for all countries.
# Variable 700 is available for all countries.
# Variable 701 is available for all countries.
# Variable 702 is available for all countries.
# Variable 703 is available for all countries.
# Variable 704 is available for all countries.
# Variable 705 is available for all countries.
# Variable 706 is available for all countries.
# Variable 707 is available for all countries.
# Variable 708 is available for all countries.
# Variable 709 is available for all countries.
# Variable 710 is available for all countries.
# Variable 711 is available for all countries.
# Variable 712 is available for all countries.
# Variable 713 is available for all countries.
# Variable 714 is available for all countries.
# Variable 715 is available for all countries.
# Variable 716 is available for all countries.
# Variable 717 is available for all countries.
# Variable 718 is available for all countries.
# Variable 719 is available for all countries.
# Variable 720 is available for all countries.
# Variable 721 is available for all countries.
# Variable 722 is available for all countries.
# Variable 723 is available for all countries.
# Variable 724 is available for all countries.
# Variable 725 is available for all countries.
# Variable 726 is available for all countries.
# Variable 727 is available for all countries.
# Variable 728 is available for all countries.
# Variable 729 is available for all countries.
# Variable 730 is available for all countries.
# Variable 731 is available for all countries.
# Variable 732 is available for all countries.
# Variable 733 is available for all countries.
# Variable 734 is available for all countries.
# Variable 735 is available for all countries.
# Variable 736 is available for all countries.
# Variable 737 is available for all countries.
# Variable 738 is available for all countries.
# Variable 739 is available for all countries.
# Variable 740 is available for all countries.
# Variable 741 is available for all countries.
# Variable 742 is available for all countries.
# Variable 743 is available for all countries.
# Variable 744 is available for all countries.
# Variable 745 is available for all countries.
# Variable 746 is available for all countries.
# Variable 747 is available for all countries.
# Variable 748 is available for all countries.
# Variable 749 is available for all countries.
# Variable 750 is available for all countries.
# Variable 751 is available for all countries.
# Variable 752 is available for all countries.
# Variable 753 is available for all countries.
# Variable 754 is available for all countries.
# Variable 755 is available for all countries.
# Variable 756 is available for all countries.
# Variable 757 is available for all countries.
# Variable 758 is available for all countries.
# Variable 759 is available for all countries.
# Variable 760 is available for all countries.
# Variable 761 is available for all countries.
# Variable 762 is available for all countries.
# Variable 763 is available for all countries.
# Variable 764 is available for all countries.
# Variable 765 is available for all countries.
# Variable 766 is available for all countries.
# Variable 767 is available for all countries.
# Variable 768 is available for all countries.
# Variable 769 is available for all countries.
# Variable 770 is available for all countries.
# Variable 771 is available for all countries.
# Variable 772 is available for all countries.
# Variable 773 is available for all countries.
# Variable 774 is available for all countries.
# Variable 775 is available for all countries.
# Variable 776 is available for all countries.
# Variable 777 is available for all countries.
# Variable 778 is available for all countries.
# Variable 779 is available for all countries.
# Variable 780 is available for all countries.
# Variable 781 is available for all countries.
# Variable 782 is available for all countries.
# Variable 783 is available for all countries.
# Variable 784 is available for all countries.
# Variable 785 is available for all countries.
# Variable 786 is available for all countries.
# Variable 787 is available for all countries.
# Variable 788 is available for all countries.
# Variable 789 is available for all countries.
# Variable 790 is available for all countries.
# Variable 791 is available for all countries.
# Variable 792 is available for all countries.
# Variable 793 is available for all countries.
# Variable 794 is available for all countries.
# Variable 795 is available for all countries.
# Variable 796 is available for all countries.
# Variable 797 is available for all countries.
# Variable 798 is available for all countries.
# Variable 799 is available for all countries.
# Variable 800 is available for all countries.
# Variable 801 is available for all countries.
# Variable 802 is available for all countries.
# Variable 803 is available for all countries.
# Variable 804 is available for all countries.
# Variable 805 is available for all countries.
# Variable 806 is available for all countries.
# Variable 807 is available for all countries.
# Variable 808 is available for all countries.
# Variable 809 is available for all countries.
# Variable 810 is available for all countries.
# Variable 811 is available for all countries.
# Variable 812 is available for all countries.
# Variable 813 is available for all countries.
# Variable 814 is available for all countries.
# Variable 815 is available for all countries.
# Variable 816 is available for all countries.
# Variable 817 is available for all countries.
# Variable 818 is available for all countries.
# Variable 819 is available for all countries.
# Variable 820 is available for all countries.
# Variable 821 is available for all countries.
# Variable 822 is available for all countries.
# Variable 823 is available for all countries.
# Variable 824 is available for all countries.
# Variable 825 is available for all countries.
# Variable 826 is available for all countries.
# Variable 827 is available for all countries.
# Variable 828 is available for all countries.
# Variable 829 is available for all countries.
# Variable 830 is available for all countries.
# Variable 831 is available for all countries.
# Variable 832 is available for all countries.
# Variable 833 is available for all countries.
# Variable 834 is available for all countries.
# Variable 835 is available for all countries.
# Variable 836 is available for all countries.
# Variable 837 is available for all countries.
# Variable 838 is available for all countries.
# Variable 839 is available for all countries.
# Variable 840 is available for all countries.
# Variable 841 is available for all countries.
# Variable 842 is available for all countries.
# Variable 843 is available for all countries.
# Variable 844 is available for all countries.
# Variable 845 is available for all countries.
# Variable 846 is available for all countries.
# Variable 847 is available for all countries.
# Variable 848 is available for all countries.
# Variable 849 is available for all countries.
# Variable 850 is available for all countries.
# Variable 851 is available for all countries.
# Variable 852 is available for all countries.
# Variable 853 is available for all countries.
# Variable 854 is available for all countries.
# Variable 855 is available for all countries.
# Variable 856 is available for all countries.
# Variable 857 is available for all countries.
# Variable 858 is available for all countries.
# Variable 859 is available for all countries.
# Variable 860 is available for all countries.
# Variable 861 is available for all countries.
# Variable 862 is available for all countries.
# Variable 863 is available for all countries.
# Variable 864 is available for all countries.
# Variable 865 is available for all countries.
# Variable 866 is available for all countries.
# Variable 867 is available for all countries.
# Variable 868 is available for all countries.
# Variable 869 is available for all countries.
# Variable 870 is available for all countries.
# Variable 871 is available for all countries.
# Variable 872 is available for all countries.
# Variable 873 is available for all countries.
# Variable 874 is available for all countries.
# Variable 875 is available for all countries.
# Variable 876 is available for all countries.
# Variable 877 is available for all countries.
# Variable 878 is available for all countries.
# Variable 879 is available for all countries.
# Variable 880 is available for all countries.
# Variable 881 is available for all countries.
# Variable 882 is available for all countries.
# Variable 883 is available for all countries.
# Variable 884 is available for all countries.
# Variable 885 is available for all countries.
# Variable 886 is available for all countries.
# Variable 887 is available for all countries.
# Variable 888 is available for all countries.
# Variable 889 is available for all countries.
# Variable 890 is available for all countries.
# Variable 891 is available for all countries.
# Variable 892 is available for all countries.
# Variable 893 is available for all countries.
# Variable 894 is available for all countries.
# Variable 895 is available for all countries.
# Variable 896 is available for all countries.
# Variable 897 is available for all countries.
# Variable 898 is available for all countries.
# Variable 899 is available for all countries.
# Variable 900 is available for all countries.
# Variable 901 is available for all countries.
# Variable 902 is available for all countries.
# Variable 903 is available for all countries.
# Variable 904 is available for all countries.
# Variable 905 is available for all countries.
# Variable 906 is available for all countries.
# Variable 907 is available for all countries.
# Variable 908 is available for all countries.
# Variable 909 is available for all countries.
# Variable 910 is available for all countries.
# Variable 911 is available for all countries.
# Variable 912 is available for all countries.
# Variable 913 is available for all countries.
# Variable 914 is available for all countries.
# Variable 915 is available for all countries.
# Variable 916 is available for all countries.
# Variable 917 is available for all countries.
# Variable 918 is available for all countries.
# Variable 919 is available for all countries.
# Variable 920 is available for all countries.
# Variable 921 is available for all countries.
# Variable 922 is available for all countries.
# Variable 923 is available for all countries.
# Variable 924 is available for all countries.
# Variable 925 is available for all countries.
# Variable 926 is available for all countries.
# Variable 927 is available for all countries.
# Variable 928 is available for all countries.
# Variable 929 is available for all countries.
# Variable 930 is available for all countries.
# Variable 931 is available for all countries.
# Variable 932 is available for all countries.
# Variable 933 is available for all countries.
# Variable 934 is available for all countries.
# Variable 935 is available for all countries.
# Variable 936 is available for all countries.
# Variable 937 is available for all countries.
# Variable 938 is available for all countries.
# Variable 939 is available for all countries.
# Variable 940 is available for all countries.
# Variable 941 is available for all countries.
# Variable 942 is available for all countries.
# Variable 943 is available for all countries.
# Variable 944 is available for all countries.
# Variable 945 is available for all countries.
# Variable 946 is available for all countries.
# Variable 947 is available for all countries.
# Variable 948 is available for all countries.
# Variable 949 is available for all countries.
# Variable 950 is available for all countries.
# Variable 951 is available for all countries.
# Variable 952 is available for all countries.
# Variable 953 is available for all countries.
# Variable 954 is available for all countries.
# Variable 955 is available for all countries.
# Variable 956 is available for all countries.
# Variable 957 is available for all countries.
# Variable 958 is available for all countries.
# Variable 959 is available for all countries.
# Variable 960 is available for all countries.
# Variable 961 is available for all countries.
# Variable 962 is available for all countries.
# Variable 963 is available for all countries.
# Variable 964 is available for all countries.
# Variable 965 is available for all countries.
# Variable 966 is available for all countries.
# Variable 967 is available for all countries.
# Variable 968 is available for all countries.
# Variable 969 is available for all countries.
# Variable 970 is available for all countries.
# Variable 971 is available for all countries.
# Variable 972 is available for all countries.
# Variable 973 is available for all countries.
# Variable 974 is available for all countries.
# Variable 975 is available for all countries.
# Variable 976 is available for all countries.
# Variable 977 is available for all countries.
# Variable 978 is available for all countries.
# Variable 979 is available for all countries.
# Variable 980 is available for all countries.
# Variable 981 is available for all countries.
# Variable 982 is available for all countries.
# Variable 983 is available for all countries.
# Variable 984 is available for all countries.
# Variable 985 is available for all countries.
# Variable 986 is available for all countries.
# Variable 987 is available for all countries.
# Variable 988 is available for all countries.
# Variable 989 is available for all countries.
# Variable 990 is available for all countries.
# Variable 991 is available for all countries.
# Variable 992 is available for all countries.
# Variable 993 is available for all countries.
# Variable 994 is available for all countries.
# Variable 995 is available for all countries.
# Variable 996 is available for all countries.
# Variable 997 is available for all countries.
# Variable 998 is available for all countries.
# Variable 999 is available for all countries.
# Variable 1000 is available for all countries.
# Variable 1001 is available for all countries.
# Variable 1002 is available for all countries.
# Variable 1003 is available for all countries.
# Variable 1004 is available for all countries.
# Variable 1005 is available for all countries.
# Variable 1006 is available for all countries.
# Variable 1007 is available for all countries.
# Variable 1008 is available for all countries.
# Variable 1009 is available for all countries.
# Variable 1010 is available for all countries.
# Variable 1011 is available for all countries.
# Variable 1012 is available for all countries.
# Variable 1013 is available for all countries.
# Variable 1014 is available for all countries.
# Variable 1015 is available for all countries.
# Variable 1016 is available for all countries.
# Variable 1017 is available for all countries.
# Variable 1018 is available for all countries.
# Variable 1019 is available for all countries.
# Variable 1020 is available for all countries.
# Variable 1021 is available for all countries.
# Variable 1022 is available for all countries.
# Variable 1023 is available for all countries.
# Variable 1024 is available for all countries.
# Variable 1025 is available for all countries.
# Variable 1026 is available for all countries.
# Variable 1027 is available for all countries.
# Variable 1028 is available for all countries.
# Variable 1029 is available for all countries.
# Variable 1030 is available for all countries.
# Variable 1031 is available for all countries.
# Variable 1032 is available for all countries.
# Variable 1033 is available for all countries.
# Variable 1034 is available for all countries.
# Variable 1035 is available for all countries.
# Variable 1036 is available for all countries.
# Variable 1037 is available for all countries.
# Variable 1038 is available for all countries.
# Variable 1039 is available for all countries.
# Variable 1040 is available for all countries.
# Variable 1041 is available for all countries.
# Variable 1042 is available for all countries.
# Variable 1043 is available for all countries.
# Variable 1044 is available for all countries.
# Variable 1045 is available for all countries.
# Variable 1046 is available for all countries.
# Variable 1047 is available for all countries.
# Variable 1048 is available for all countries.
# Variable 1049 is available for all countries.
# Variable 1050 is available for all countries.
# Variable 1051 is available for all countries.
# Variable 1052 is available for all countries.
# Variable 1053 is available for all countries.
# Variable 1054 is available for all countries.
# Variable 1055 is available for all countries.
# Variable 1056 is available for all countries.
# Variable 1057 is available for all countries.
# Variable 1058 is available for all countries.
# Variable 1059 is available for all countries.
# Variable 1060 is available for all countries.
# Variable 1061 is available for all countries.
# Variable 1062 is available for all countries.
# Variable 1063 is available for all countries.
# Variable 1064 is available for all countries.
# Variable 1065 is available for all countries.
# Variable 1066 is available for all countries.
# ...
# Variable 15994 is available for all countries.
# Variable 15995 is available for all countries.
# Variable 15996 is available for all countries.
# Variable 15997 is available for all countries.
# Variable 15998 is available for all countries.
# Variable 15999 is available for all countries.
# Variable 16000 is available for all countries.
# Variable 16001 is available for all countries.
# Variable 16002 is available for all countries.
# Variable 16003 is available for all countries.
# Variable 16004 is available for all countries.
# Variable 16005 is available for all countries.
# Variable 16006 is available for all countries.
# Variable 16007 is available for all countries.
# Variable 16008 is available for all countries.
# Variable 16009 is available for all countries.
# Variable 16010 is available for all countries.
# Variable 16011 is available for all countries.
# Variable 16012 is available for all countries.
# Variable 16013 is available for all countries.
# Variable 16014 is available for all countries.
# Variable 16015 is available for all countries.
# Variable 16016 is available for all countries.
# Variable 16017 is available for all countries.
# Variable 16018 is available for all countries.
# Variable 16019 is available for all countries.
# Variable 16020 is available for all countries.
# Variable 16021 is available for all countries.
# Variable 16022 is available for all countries.
# Variable 16023 is available for all countries.
# Variable 16024 is available for all countries.
# Variable 16025 is available for all countries.
# Variable 16026 is available for all countries.
# Variable 16027 is available for all countries.
# Variable 16028 is available for all countries.
# Variable 16029 is available for all countries.
# Variable 16030 is available for all countries.
# Variable 16031 is available for all countries.
# Variable 16032 is available for all countries.
# Variable 16033 is available for all countries.
# Variable 16034 is available for all countries.
# Variable 16035 is available for all countries.
# Variable 16036 is available for all countries.
# Variable 16037 is available for all countries.
# Variable 16038 is available for all countries.
# Variable 16039 is available for all countries.
# Variable 16040 is available for all countries.
# Variable 16041 is available for all countries.
# Variable 16042 is available for all countries.
# Variable 16043 is available for all countries.
# Variable 16044 is available for all countries.
# Variable 16045 is available for all countries.
# Variable 16046 is available for all countries.
# Variable 16047 is available for all countries.
# Variable 16048 is available for all countries.
# Variable 16049 is available for all countries.
# Variable 16050 is available for all countries.
# Variable 16051 is available for all countries.
# Variable 16052 is available for all countries.
# Variable 16053 is available for all countries.
# Variable 16054 is available for all countries.
# Variable 16055 is available for all countries.
# Variable 16056 is available for all countries.
# Variable 16057 is available for all countries.
# Variable 16058 is available for all countries.
# Variable 16059 is available for all countries.
# Variable 16060 is available for all countries.
# Variable 16061 is available for all countries.
# Variable 16062 is available for all countries.
# Variable 16063 is available for all countries.
# Variable 16064 is available for all countries.
# Variable 16065 is available for all countries.
# Variable 16066 is available for all countries.
# Variable 16067 is available for all countries.
# Variable 16068 is available for all countries.
# Variable 16069 is available for all countries.
# Variable 16070 is available for all countries.
# Variable 16071 is available for all countries.
# Variable 16072 is available for all countries.
# Variable 16073 is available for all countries.
# Variable 16074 is available for all countries.
# Variable 16075 is available for all countries.
# Variable 16076 is available for all countries.
# Variable 16077 is available for all countries.
# Variable 16078 is available for all countries.
# Variable 16079 is available for all countries.
# Variable 16080 is available for all countries.
# Variable 16081 is available for all countries.
# Variable 16082 is available for all countries.
# Variable 16083 is available for all countries.
# Variable 16084 is available for all countries.
# Variable 16085 is available for all countries.
# Variable 16086 is available for all countries.
# Variable 16087 is available for all countries.
# Variable 16088 is available for all countries.
# Variable 16089 is available for all countries.
# Variable 16090 is available for all countries.
# Variable 16091 is available for all countries.
# Variable 16092 is available for all countries.
# Variable 16093 is available for all countries.
# Variable 16094 is available for all countries.
# Variable 16095 is available for all countries.
# Variable 16096 is available for all countries.
# Variable 16097 is available for all countries.
# Variable 16098 is available for all countries.
# Variable 16099 is available for all countries.
# Variable 16100 is available for all countries.
# Variable 16101 is available for all countries.
# Variable 16102 is available for all countries.
# Variable 16103 is available for all countries.
# Variable 16104 is available for all countries.
# Variable 16105 is available for all countries.
# Variable 16106 is available for all countries.
# Variable 16107 is available for all countries.
# Variable 16108 is available for all countries.
# Variable 16109 is available for all countries.
# Variable 16110 is available for all countries.
# Variable 16111 is available for all countries.
# Variable 16112 is available for all countries.
# Variable 16113 is available for all countries.
# Variable 16114 is available for all countries.
# Variable 16115 is available for all countries.
# Variable 16116 is available for all countries.
# Variable 16117 is available for all countries.
# Variable 16118 is available for all countries.
# Variable 16119 is available for all countries.
# Variable 16120 is available for all countries.
# Variable 16121 is available for all countries.
# Variable 16122 is available for all countries.
# Variable 16123 is available for all countries.
# Variable 16124 is available for all countries.
# Variable 16125 is available for all countries.
# Variable 16126 is available for all countries.
# Variable 16127 is available for all countries.
# Variable 16128 is available for all countries.
# Variable 16129 is available for all countries.
# Variable 16130 is available for all countries.
# Variable 16131 is available for all countries.
# Variable 16132 is available for all countries.
# Variable 16133 is available for all countries.
# Variable 16134 is available for all countries.
# Variable 16135 is available for all countries.
# Variable 16136 is available for all countries.
# Variable 16137 is available for all countries.
# Variable 16138 is available for all countries.
# Variable 16139 is available for all countries.
# Variable 16140 is available for all countries.
# Variable 16141 is available for all countries.
# Variable 16142 is available for all countries.
# Variable 16143 is available for all countries.
# Variable 16144 is available for all countries.
# Variable 16145 is available for all countries.
# Variable 16146 is available for all countries.
# Variable 16147 is available for all countries.
# Variable 16148 is available for all countries.
# Variable 16149 is available for all countries.
# Variable 16150 is available for all countries.
# Variable 16151 is available for all countries.
# Variable 16152 is available for all countries.
# Variable 16153 is available for all countries.
# Variable 16154 is available for all countries.
# Variable 16155 is available for all countries.
# Variable 16156 is available for all countries.
# Variable 16157 is available for all countries.
# Variable 16158 is available for all countries.
# Variable 16159 is available for all countries.
# Variable 16160 is available for all countries.
# Variable 16161 is available for all countries.
# Variable 16162 is available for all countries.
# Variable 16163 is available for all countries.
# Variable 16164 is available for all countries.
# Variable 16165 is available for all countries.
# Variable 16166 is available for all countries.
# Variable 16167 is available for all countries.
# Variable 16168 is available for all countries.
# Variable 16169 is available for all countries.
# Variable 16170 is available for all countries.
# Variable 16171 is available for all countries.
# Variable 16172 is available for all countries.
# Variable 16173 is available for all countries.
# Variable 16174 is available for all countries.
# Variable 16175 is available for all countries.
# Variable 16176 is available for all countries.
# Variable 16177 is available for all countries.
# Variable 16178 is available for all countries.
# Variable 16179 is available for all countries.
# Variable 16180 is available for all countries.
# Variable 16181 is available for all countries.
# Variable 16182 is available for all countries.
# Variable 16183 is available for all countries.
# Variable 16184 is available for all countries.
# Variable 16185 is available for all countries.
# Variable 16186 is available for all countries.
# Variable 16187 is available for all countries.
# Variable 16188 is available for all countries.
# Variable 16189 is available for all countries.
# Variable 16190 is available for all countries.
# Variable 16191 is available for all countries.
# Variable 16192 is available for all countries.
# Variable 16193 is available for all countries.
# Variable 16194 is available for all countries.
# Variable 16195 is available for all countries.
# Variable 16196 is available for all countries.
# Variable 16197 is available for all countries.
# Variable 16198 is available for all countries.
# Variable 16199 is available for all countries.
# Variable 16200 is available for all countries.
# Variable 16201 is available for all countries.
# Variable 16202 is available for all countries.
# Variable 16203 is available for all countries.
# Variable 16204 is available for all countries.
# Variable 16205 is available for all countries.
# Variable 16206 is available for all countries.
# Variable 16207 is available for all countries.
# Variable 16208 is available for all countries.
# Variable 16209 is available for all countries.
# Variable 16210 is available for all countries.
# Variable 16211 is available for all countries.
# Variable 16212 is available for all countries.
# Variable 16213 is available for all countries.
# Variable 16214 is available for all countries.
# Variable 16215 is available for all countries.
# Variable 16216 is available for all countries.
# Variable 16217 is available for all countries.
# Variable 16218 is available for all countries.
# Variable 16219 is available for all countries.
# Variable 16220 is available for all countries.
# Variable 16221 is available for all countries.
# Variable 16222 is available for all countries.
# Variable 16223 is available for all countries.
# Variable 16224 is available for all countries.
# Variable 16225 is available for all countries.
# Variable 16226 is available for all countries.
# Variable 16227 is available for all countries.
# Variable 16228 is available for all countries.
# Variable 16229 is available for all countries.
# Variable 16230 is available for all countries.
# Variable 16231 is available for all countries.
# Variable 16232 is available for all countries.
# Variable 16233 is available for all countries.
# Variable 16234 is available for all countries.
# Variable 16235 is available for all countries.
# Variable 16236 is available for all countries.
# Variable 16237 is available for all countries.
# Variable 16238 is available for all countries.
# Variable 16239 is available for all countries.
# Variable 16240 is available for all countries.
# Variable 16241 is available for all countries.
# Variable 16242 is available for all countries.
# Variable 16243 is available for all countries.
# Variable 16244 is available for all countries.
# Variable 16245 is available for all countries.
# Variable 16246 is available for all countries.
# Variable 16247 is available for all countries.
# Variable 16248 is available for all countries.
# Variable 16249 is available for all countries.
# Variable 16250 is available for all countries.
# Variable 16251 is available for all countries.
# Variable 16252 is available for all countries.
# Variable 16253 is available for all countries.
# Variable 16254 is available for all countries.
# Variable 16255 is available for all countries.
# Variable 16256 is available for all countries.
# Variable 16257 is available for all countries.
# Variable 16258 is available for all countries.
# Variable 16259 is available for all countries.
# Variable 16260 is available for all countries.
# Variable 16261 is available for all countries.
# Variable 16262 is available for all countries.
# Variable 16263 is available for all countries.
# Variable 16264 is available for all countries.
# Variable 16265 is available for all countries.
# Variable 16266 is available for all countries.
# Variable 16267 is available for all countries.
# Variable 16268 is available for all countries.
# Variable 16269 is available for all countries.
# Variable 16270 is available for all countries.
# Variable 16271 is available for all countries.
# Variable 16272 is available for all countries.
# Variable 16273 is available for all countries.
# Variable 16274 is available for all countries.
# Variable 16275 is available for all countries.
# Variable 16276 is available for all countries.
# Variable 16277 is available for all countries.
# Variable 16278 is available for all countries.
# Variable 16279 is available for all countries.
# Variable 16280 is available for all countries.
# Variable 16281 is available for all countries.
# Variable 16282 is available for all countries.
# Variable 16283 is available for all countries.
# Variable 16284 is available for all countries.
# Variable 16285 is available for all countries.
# Variable 16286 is available for all countries.
# Variable 16287 is available for all countries.
# Variable 16288 is available for all countries.
# Variable 16289 is available for all countries.
# Variable 16290 is available for all countries.
# Variable 16291 is available for all countries.
# Variable 16292 is available for all countries.
# Variable 16293 is available for all countries.
# Variable 16294 is available for all countries.
# Variable 16295 is available for all countries.
# Variable 16296 is available for all countries.
# Variable 16297 is available for all countries.
# Variable 16298 is available for all countries.
# Variable 16299 is available for all countries.
# Variable 16300 is available for all countries.
# Variable 16301 is available for all countries.
# Variable 16302 is available for all countries.
# Variable 16303 is available for all countries.
# Variable 16304 is available for all countries.
# Variable 16305 is available for all countries.
# Variable 16306 is available for all countries.
# Variable 16307 is available for all countries.
# Variable 16308 is available for all countries.
# Variable 16309 is available for all countries.
# Variable 16310 is available for all countries.
# Variable 16311 is available for all countries.
# Variable 16312 is available for all countries.
# Variable 16313 is available for all countries.
# Variable 16314 is available for all countries.
# Variable 16315 is available for all countries.
# Variable 16316 is available for all countries.
# Variable 16317 is available for all countries.
# Variable 16318 is available for all countries.
# Variable 16319 is available for all countries.
# Variable 16320 is available for all countries.
# Variable 16321 is available for all countries.
# Variable 16322 is available for all countries.
# Variable 16323 is available for all countries.
# Variable 16324 is available for all countries.
# Variable 16325 is available for all countries.
# Variable 16326 is available for all countries.
# Variable 16327 is available for all countries.
# Variable 16328 is available for all countries.
# Variable 16329 is available for all countries.
# Variable 16330 is available for all countries.
# Variable 16331 is available for all countries.
# Variable 16332 is available for all countries.
# Variable 16333 is available for all countries.

# %%
print(variable_availability.head())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 print(variable_availability.head())
#
# NameError: name 'variable_availability' is not defined
