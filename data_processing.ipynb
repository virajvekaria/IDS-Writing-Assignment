# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import warnings

# Ignore warnings for cleaner output
warnings.filterwarnings('ignore')
# Import functions from our exploration module
from data_exploration import read_wid_csv, explore_countries, explore_country_data, compare_variable_availability

# %%
INCOME_VARIABLES = ['aptincf992', 'adiinci992', 'aptinci992', 'gfaincj992'] 
WEALTH_VARIABLES = ['bhwealj992']
SHARE_VARIABLES = ['spllinf992']

# Define percentiles of interest (based on what's available in your dataset)
TOP_PERCENTILES = ['p90p100', 'p99p100', 'p99.9p100']  # Top 10%, Top 1%, Top 0.1%
BOTTOM_PERCENTILES = ['p0p50', 'p0p90']  # Bottom 50%, Bottom 90%
MIDDLE_PERCENTILES = ['p50p90']  # Middle 40%

# Countries to include in our analysis
# We'll select a diverse set of countries from different regions and development levels
COUNTRIES_TO_ANALYZE = [
    # High-income countries
    'US',   # United States
    'FR',   # France
    'DE',   # Germany
    'GB',   # United Kingdom
    'JP',   # Japan
    
    # Upper-middle income countries
    'BR',   # Brazil
    'CN',   # China
    'RU',   # Russia
    'ZA',   # South Africa
    
    # Lower-middle and low-income countries
    'IN',   # India
    'ID',   # Indonesia
    'NG',   # Nigeria
    'EG'    # Egypt
]

# %%
# Function to load country data with selected variables
def load_country_data(country_code, directory='wid_all_data'):
    """
    Load specific inequality variables for a given country.
    
    Args:
        country_code (str): Two-letter country code
        directory (str): Path to WID data directory
    
    Returns:
        tuple: (data_df, metadata_df) for the country
    """
    data_path = os.path.join(directory, f'WID_data_{country_code}.csv')
    metadata_path = os.path.join(directory, f'WID_metadata_{country_code}.csv')
    
    if not os.path.exists(data_path) or not os.path.exists(metadata_path):
        print(f"Data or metadata not found for {country_code}")
        return None, None
    
    data_df = read_wid_csv(data_path)
    metadata_df = read_wid_csv(metadata_path)
    
    return data_df, metadata_df

# Function to create a dataset for a specific inequality metric
def create_inequality_dataset(countries, variable_codes, percentiles, directory='wid_all_data'):
    """
    Create a dataset comparing specific inequality variables across countries.
    Will try each variable code in the list until one works.
    
    Args:
        countries (list): List of country codes
        variable_codes (list or str): WID variable code(s) to try
        percentiles (list): List of percentile codes (e.g., ['p99p100', 'p0p50'])
        directory (str): Path to WID data directory
    
    Returns:
        pd.DataFrame: Combined dataset with inequality data
    """
    # Convert single variable code to list for consistent processing
    if isinstance(variable_codes, str):
        variable_codes = [variable_codes]
    
    # Load country information for names
    countries_info = explore_countries(directory)
    if countries_info is None:
        print("Could not load country information")
        return None
    
    countries_df = countries_info['countries_df']
    country_name_map = dict(zip(countries_df['alpha2'], countries_df['shortname']))
    
    # Try each variable code until we find one that works
    for variable_code in variable_codes:
        print(f"Trying variable code: {variable_code}")
        combined_df = pd.DataFrame()
        
        for country in countries:
            data_df, metadata_df = load_country_data(country, directory)
            
            if data_df is None:
                print(f"  Skipping {country} - could not load data")
                continue
            
            # Filter for the requested variable and percentiles
            filtered_df = data_df[(data_df['variable'] == variable_code) & 
                                (data_df['percentile'].isin(percentiles))]
            
            if filtered_df.empty:
                print(f"  No data for {variable_code} with percentiles {percentiles} in {country}")
                continue
            
            # Add country name
            filtered_df['country_code'] = country
            filtered_df['country_name'] = country_name_map.get(country, country)
            
            # Append to combined dataset
            combined_df = pd.concat([combined_df, filtered_df])
            print(f"  Found data for {variable_code} for {country}: {len(filtered_df)} rows")
        
        if not combined_df.empty:
            print(f"Successfully found data for variable {variable_code}")
            return combined_df
    
    print(f"No data found for any of these variables: {variable_codes} across specified countries and percentiles")
    return None

# Function to create a comparative dataset of income/wealth distribution over time
def create_time_series_dataset(variable_codes, percentile, countries=COUNTRIES_TO_ANALYZE, directory='wid_all_data'):
    """
    Create a dataset of inequality metrics over time for multiple countries.
    Will try multiple variable codes until one works.
    
    Args:
        variable_codes (list or str): WID variable code(s) to try
        percentile (str): Percentile code
        countries (list): List of country codes
        directory (str): Path to WID data directory
    
    Returns:
        pd.DataFrame: Time series data for the specified variable and percentile
    """
    # Convert single variable code to list for consistent processing
    if isinstance(variable_codes, str):
        variable_codes = [variable_codes]
    
    # Get variable description (try to get from first variable code, but not critical)
    variable_desc = None
    try:
        sample_country = countries[0]
        _, metadata_df = load_country_data(sample_country, directory)
        
        if metadata_df is not None:
            for var_code in variable_codes:
                var_info = metadata_df[metadata_df['variable'] == var_code]
                if not var_info.empty:
                    variable_desc = var_info.iloc[0]['simpledes']
                    break
    except:
        pass
    
    # Try to create dataset with any of the provided variable codes
    dataset = create_inequality_dataset(countries, variable_codes, [percentile], directory)
    
    if dataset is not None:
        # Pivot to have years as columns and countries as rows for easier plotting
        dataset = dataset.sort_values(['country_name', 'year'])
        
        # Add metadata
        dataset.attrs['variable_code'] = dataset['variable'].iloc[0]  # Use the actual variable code that worked
        dataset.attrs['variable_desc'] = variable_desc
        dataset.attrs['percentile'] = percentile
    
    return dataset

# Function to create a dataset for GDP per capita
def create_gdp_dataset(countries=COUNTRIES_TO_ANALYZE, directory='wid_all_data'):
    """
    Create a dataset of GDP per capita for comparison with inequality metrics.
    Using national income per adult as a proxy.
    
    Args:
        countries (list): List of country codes
        directory (str): Path to WID data directory
    
    Returns:
        pd.DataFrame: GDP per capita data
    """
    # Try several possible GDP/income per adult variables
    gdp_variables = ['anninc992i', 'aptinc992i', 'adiinci992', 'adiincf992']
    
    # We don't need a percentile for this aggregate measure, but WID still requires one
    # p0p100 represents the entire population
    gdp_data = create_inequality_dataset(countries, gdp_variables, ['p0p100'], directory)
    
    if gdp_data is not None:
        # Add variable description
        var_code = gdp_data['variable'].iloc[0]
        gdp_data.attrs['variable_desc'] = f'Income per Adult ({var_code})'
        
        # Convert to common currency (USD) using most recent PPP rates
        # This would require additional implementation to get PPP conversion rates
        # For simplicity, we'll leave the values in local currency
    
    return gdp_data

# Function to create a cross-sectional dataset with the available variables
def create_cross_sectional_dataset(countries=COUNTRIES_TO_ANALYZE, year=2020, directory='wid_all_data'):
    """
    Create a cross-sectional dataset combining multiple inequality metrics for a specific year.
    Adapts to find available variables in the dataset.
    
    Args:
        countries (list): List of country codes
        year (int): Reference year for the cross-section
        directory (str): Path to WID data directory
    
    Returns:
        pd.DataFrame: Combined dataset with multiple inequality metrics
    """
    print("Building cross-sectional dataset with available metrics...")
    
    # Initialize results dataframe with country codes
    countries_info = explore_countries(directory)
    country_name_map = {}
    
    if countries_info is not None and 'countries_df' in countries_info:
        countries_df = countries_info['countries_df']
        country_name_map = dict(zip(countries_df['alpha2'], countries_df['shortname']))
    
    # Create the base dataframe with country information
    result_df = pd.DataFrame({
        'country_code': countries,
        'country_name': [country_name_map.get(c, c) for c in countries]
    })
    
    # Identify what variables we have available from our time series datasets
    available_datasets = []
    
    # Try loading income variables for different percentiles
    for percentile in TOP_PERCENTILES + BOTTOM_PERCENTILES:
        for var_prefix in ['a', 's']:  # Try both average and share variables
            for var_type in INCOME_VARIABLES:
                # Only use the variable type part (e.g., 'ptincf992' from 'aptincf992')
                var_base = var_type[1:] if var_type.startswith('a') or var_type.startswith('s') else var_type
                test_var = f"{var_prefix}{var_base}"
                
                dataset = create_inequality_dataset(countries, [test_var], [percentile], directory)
                if dataset is not None and not dataset.empty:
                    metric_name = f"{var_prefix}_{var_base}_{percentile}"
                    available_datasets.append({
                        'name': metric_name,
                        'dataset': dataset,
                        'variable': test_var,
                        'percentile': percentile
                    })
                    print(f"  Found data for {test_var} with percentile {percentile}")
    
    # Try loading wealth variables
    for percentile in TOP_PERCENTILES + BOTTOM_PERCENTILES:
        for wealth_var in WEALTH_VARIABLES:
            dataset = create_inequality_dataset(countries, [wealth_var], [percentile], directory)
            if dataset is not None and not dataset.empty:
                metric_name = f"{wealth_var}_{percentile}"
                available_datasets.append({
                    'name': metric_name,
                    'dataset': dataset,
                    'variable': wealth_var,
                    'percentile': percentile
                })
                print(f"  Found data for {wealth_var} with percentile {percentile}")
    
    # Try loading GDP or income per adult variables
    gdp_data = create_gdp_dataset(countries, directory)
    if gdp_data is not None and not gdp_data.empty:
        var_code = gdp_data['variable'].iloc[0]
        available_datasets.append({
            'name': f"{var_code}_per_adult",
            'dataset': gdp_data,
            'variable': var_code,
            'percentile': 'p0p100'
        })
        print(f"  Found GDP/income per adult data: {var_code}")
    
    # Extract values for the reference year (or closest available)
    for dataset_info in available_datasets:
        df = dataset_info['dataset']
        name = dataset_info['name']
        
        # Initialize new columns with NaN
        result_df[f"{name}_value"] = np.nan
        result_df[f"{name}_year"] = np.nan
        
        # Process each country
        for country in result_df['country_code']:
            country_data = df[df['country_code'] == country]
            
            if not country_data.empty:
                # Try to get the exact year first
                year_data = country_data[country_data['year'] == year]
                
                # If exact year not available, find closest year
                if year_data.empty:
                    available_years = country_data['year'].unique()
                    if len(available_years) > 0:
                        closest_year = available_years[np.abs(available_years - year).argmin()]
                        year_data = country_data[country_data['year'] == closest_year]
                
                # If we found data, add it to the result
                if not year_data.empty:
                    row_idx = result_df[result_df['country_code'] == country].index[0]
                    result_df.loc[row_idx, f"{name}_value"] = year_data['value'].iloc[0]
                    result_df.loc[row_idx, f"{name}_year"] = year_data['year'].iloc[0]
    
    # Add region information if available
    if countries_info is not None and 'countries_df' in countries_info:
        countries_df = countries_info['countries_df']
        
        for idx, row in result_df.iterrows():
            country_info = countries_df[countries_df['alpha2'] == row['country_code']]
            if not country_info.empty:
                result_df.loc[idx, 'region'] = country_info['region'].iloc[0]
                result_df.loc[idx, 'region2'] = country_info['region2'].iloc[0]
    
    # Display summary of metrics found
    value_cols = [col for col in result_df.columns if col.endswith('_value')]
    print(f"Created cross-sectional dataset with {len(value_cols)} metrics for {len(result_df)} countries")
    
    return result_df

# Function to create a dataset comparing changes in inequality over time
def create_inequality_change_dataset(countries=COUNTRIES_TO_ANALYZE, 
                                     variable_codes=INCOME_VARIABLES,
                                     percentile='p99p100', 
                                     start_year=1980, 
                                     end_year=2020,
                                     directory='wid_all_data'):
    """
    Create a dataset showing changes in inequality metrics over time.
    
    Args:
        countries (list): List of country codes
        variable_codes (list or str): WID variable code(s) to try
        percentile (str): Percentile code
        start_year (int): Starting year for change calculation
        end_year (int): Ending year for change calculation
        directory (str): Path to WID data directory
    
    Returns:
        pd.DataFrame: Dataset with inequality changes
    """
    # Get the time series data
    time_series = create_time_series_dataset(variable_codes, percentile, countries, directory)
    
    if time_series is None:
        return None
    
    # Calculate changes
    change_data = []
    
    # Group by country
    for country, group in time_series.groupby('country_code'):
        group = group.sort_values('year')
        country_name = group['country_name'].iloc[0]
        
        # Try to get values for exact years
        start_data = group[group['year'] == start_year]
        end_data = group[group['year'] == end_year]
        
        # If exact years not available, find closest years
        if start_data.empty:
            available_years = group['year'].unique()
            closest_start = available_years[np.abs(available_years - start_year).argmin()]
            start_data = group[group['year'] == closest_start]
        
        if end_data.empty:
            available_years = group['year'].unique()
            closest_end = available_years[np.abs(available_years - end_year).argmin()]
            end_data = group[group['year'] == closest_end]
        
        # Skip if we don't have data for both periods
        if start_data.empty or end_data.empty:
            print(f"Insufficient data for {country} to calculate changes")
            continue
        
        # Calculate changes
        start_value = start_data['value'].iloc[0]
        end_value = end_data['value'].iloc[0]
        actual_start_year = start_data['year'].iloc[0]
        actual_end_year = end_data['year'].iloc[0]
        
        absolute_change = end_value - start_value
        percent_change = (absolute_change / start_value) * 100 if start_value != 0 else np.nan
        
        change_data.append({
            'country_code': country,
            'country_name': country_name,
            'start_year': actual_start_year,
            'end_year': actual_end_year,
            'start_value': start_value,
            'end_value': end_value,
            'absolute_change': absolute_change,
            'percent_change': percent_change
        })
    
    # Convert to DataFrame
    change_df = pd.DataFrame(change_data)
    
    if change_df.empty:
        return None
    
    # Add metadata
    change_df.attrs['variable_code'] = time_series.attrs.get('variable_code', '')
    change_df.attrs['variable_desc'] = time_series.attrs.get('variable_desc', '')
    change_df.attrs['percentile'] = percentile
    
    return change_df

# Function to combine income and wealth inequality data for correlation analysis
def create_correlation_dataset(countries=COUNTRIES_TO_ANALYZE, reference_year=2020, directory='wid_all_data'):
    """
    Create a dataset to analyze correlations between income and wealth inequality.
    
    Args:
        countries (list): List of country codes
        reference_year (int): Reference year for the cross-section
        directory (str): Path to WID data directory
    
    Returns:
        pd.DataFrame: Dataset with income and wealth inequality metrics
    """
    # Get cross-sectional data
    cross_section = create_cross_sectional_dataset(countries, reference_year, directory)
    
    if cross_section is None or cross_section.empty:
        print("Could not create cross-sectional dataset for correlation analysis")
        return None
    
    # Create metrics for correlation analysis
    corr_metrics = [
        ('top1_income_share', 'top1_wealth_share'),
        ('top10_income_share', 'top10_wealth_share'),
        ('bottom50_income_share', 'bottom50_wealth_share'),
        ('gdp_per_adult', 'top1_income_share'),
        ('gdp_per_adult', 'top1_wealth_share')
    ]
    
    # Calculate correlations
    correlations = {}
    
    for x_var, y_var in corr_metrics:
        if x_var in cross_section.columns and y_var in cross_section.columns:
            # Filter out NaN values
            valid_data = cross_section[[x_var, y_var]].dropna()
            
            if len(valid_data) >= 5:  # Require at least 5 countries for meaningful correlation
                corr, p_value = stats.pearsonr(valid_data[x_var], valid_data[y_var])
                correlations[f'{x_var}_vs_{y_var}'] = {
                    'correlation': corr,
                    'p_value': p_value,
                    'n': len(valid_data)
                }
    
    # Add correlations to dataset attributes
    cross_section.attrs['correlations'] = correlations
    
    return cross_section

# Main function to prepare all datasets
def prepare_all_datasets(directory='wid_all_data'):
    """
    Prepare all datasets needed for our inequality analysis.
    
    Args:
        directory (str): Path to WID data directory
    
    Returns:
        dict: Dictionary of prepared datasets
    """
    print("Preparing inequality datasets...")
    
    datasets = {}
    
    # 1. Time series of top 1% income share
    print("Creating top 1% income share time series...")
    datasets['top1_income_time'] = create_time_series_dataset(
        INCOME_VARIABLES, 'p99p100', COUNTRIES_TO_ANALYZE, directory)
    
    # 2. Time series of top 10% income share 
    print("Creating top 10% income share time series...")
    datasets['top10_income_time'] = create_time_series_dataset(
        INCOME_VARIABLES, 'p90p100', COUNTRIES_TO_ANALYZE, directory)
    
    # 3. Time series of bottom 50% income share
    print("Creating bottom 50% income share time series...")
    datasets['bottom50_income_time'] = create_time_series_dataset(
        INCOME_VARIABLES, 'p0p50', COUNTRIES_TO_ANALYZE, directory)
    
    # 4. Time series of top 1% wealth share
    print("Creating top 1% wealth share time series...")
    datasets['top1_wealth_time'] = create_time_series_dataset(
        WEALTH_VARIABLES, 'p99p100', COUNTRIES_TO_ANALYZE, directory)
    
    # 5. Try to create a dataset with share variables if available
    print("Creating share variable time series if available...")
    if SHARE_VARIABLES:
        for percentile in TOP_PERCENTILES + BOTTOM_PERCENTILES:
            dataset_name = f"share_{percentile}_time"
            datasets[dataset_name] = create_time_series_dataset(
                SHARE_VARIABLES, percentile, COUNTRIES_TO_ANALYZE, directory)
    
    # 6. Cross-sectional data for most recent year
    print("Creating cross-sectional dataset...")
    datasets['cross_section'] = create_cross_sectional_dataset(
        COUNTRIES_TO_ANALYZE, 2020, directory)
    
    # 7. Changes in income inequality (1980-2020)
    print("Creating income inequality change dataset...")
    datasets['income_change'] = create_inequality_change_dataset(
        COUNTRIES_TO_ANALYZE, INCOME_VARIABLES, 'p99p100', 1980, 2020, directory)
    
    # 8. Changes in wealth inequality (1980-2020)
    print("Creating wealth inequality change dataset...")
    datasets['wealth_change'] = create_inequality_change_dataset(
        COUNTRIES_TO_ANALYZE, WEALTH_VARIABLES, 'p99p100', 1980, 2020, directory)
    
    # 9. Correlation dataset
    print("Creating correlation dataset...")
    datasets['correlation'] = create_correlation_dataset(
        COUNTRIES_TO_ANALYZE, 2020, directory)
    
    # Save datasets to CSV files
    output_dir = 'output'
    os.makedirs(output_dir, exist_ok=True)
    
    for name, df in datasets.items():
        if df is not None and not df.empty:
            df.to_csv(os.path.join(output_dir, f'{name}.csv'), index=False)
            print(f"Saved {name}.csv")
    
    print("Dataset preparation complete!")
    return datasets

# %%
# prepared_data = prepare_all_datasets()

dataset = create_inequality_dataset(countries=['US', 'FR'], 
                                    variable_codes=INCOME_VARIABLES, 
                                    percentiles=['p99p100'], 
                                    directory='wid_all_data')

# %%
variable_availability = compare_variable_availability(COUNTRIES_TO_ANALYZE)
# Out:
# Availability DataFrame:
#   country    variable  available  year_min  year_max  year_count
# 0      US  ehfcari999       True      1990      2020          31
# 1      US  ehfghdi999       True      1990      2020          31
# 2      US  ehfghgi999       True      1980      2020          41
# 3      US  ehfghni999       True      1990      2020          31
# 4      US  ehfghoi999       True      1990      2020          31
# Pivot Table:
# country        BR     CN    DE     EG    FR    GB     ID     IN     JP     NG     RU     US     ZA
# variable
# acaincj992  False  False  True  False  True  True  False  False  False  False  False  False  False
# accmhni992   True  False  True   True  True  True   True  False   True  False   True   True  False
# accmhni999   True  False  True   True  True  True   True  False   True  False   True   True  False
# accmhoi992   True  False  True   True  True  True   True  False   True  False   True   True  False
# accmhoi999   True  False  True   True  True  True   True  False   True  False   True   True  False

# %%
# Print variables that are present for every country
for var, series in variable_availability.iterrows():
    # print(var)
    if all(series):
        print(f"Variable {var} is available for all countries.")
    else:
        continue
        # print(f"Variable {var} is not available for all countries.")
# Out:
# Variable xlcyuxi999 is available for all countries.
# Variable eifghoi999 is available for all countries.
# Variable wfdirxi999 is available for all countries.
# Variable wfdipxi999 is available for all countries.
# Variable bptincj992 is available for all countries.
# Variable wfdinxi999 is available for all countries.
# Variable egfcari999 is available for all countries.
# Variable egfghgi999 is available for all countries.
# Variable egfghoi999 is available for all countries.
# Variable ehfcari999 is available for all countries.
# Variable ehfghdi999 is available for all countries.
# Variable ehfghgi999 is available for all countries.
# Variable ehfghni999 is available for all countries.
# Variable ehfghoi999 is available for all countries.
# Variable eifcari999 is available for all countries.
# Variable eifghgi999 is available for all countries.
# Variable enfcari999 is available for all countries.
# Variable wfinrxi999 is available for all countries.
# Variable enfghgi999 is available for all countries.
# Variable enfghoi999 is available for all countries.
# Variable enncari999 is available for all countries.
# Variable ennghgi999 is available for all countries.
# Variable ennghoi999 is available for all countries.
# Variable entcari999 is available for all countries.
# Variable entcnai999 is available for all countries.
# Variable entghgi999 is available for all countries.
# Variable entghoi999 is available for all countries.
# Variable entgnai999 is available for all countries.
# Variable entonai999 is available for all countries.
# Variable eofcari999 is available for all countries.
# Variable eofghgi999 is available for all countries.
# Variable eofghoi999 is available for all countries.
# Variable wfinpxi999 is available for all countries.
# Variable wfkanxi999 is available for all countries.
# Variable atsopxi992 is available for all countries.
# Variable atsxrxi992 is available for all countries.
# Variable atsorxi992 is available for all countries.
# Variable atsorxi999 is available for all countries.
# Variable atstnxi992 is available for all countries.
# Variable atstnxi999 is available for all countries.
# Variable atstpxi992 is available for all countries.
# Variable atstpxi999 is available for all countries.
# Variable atstrxi992 is available for all countries.
# Variable atstrxi999 is available for all countries.
# Variable atsvnxi992 is available for all countries.
# Variable atsvnxi999 is available for all countries.
# Variable atsvpxi992 is available for all countries.
# Variable atsvpxi999 is available for all countries.
# Variable atsvrxi992 is available for all countries.
# Variable atsvrxi999 is available for all countries.
# Variable atsxrxi999 is available for all countries.
# Variable wfkapxi999 is available for all countries.
# Variable bdiincj992 is available for all countries.
# Variable wgwfini999 is available for all countries.
# Variable wgweali999 is available for all countries.
# Variable wgwdebi999 is available for all countries.
# Variable wgwbusi999 is available for all countries.
# Variable bhwealj992 is available for all countries.
# Variable wgpsgei999 is available for all countries.
# Variable wgdproi999 is available for all countries.
# Variable wftaxxi999 is available for all countries.
# Variable wfsubxi999 is available for all countries.
# Variable wflciri999 is available for all countries.
# Variable wflcipi999 is available for all countries.
# Variable wflcini999 is available for all countries.
# Variable wfkarxi999 is available for all countries.
# Variable wexpgoi999 is available for all countries.
# Variable wenvgei999 is available for all countries.
# Variable gdiincj992 is available for all countries.
# Variable kofghoi999 is available for all countries.
# Variable knfcari999 is available for all countries.
# Variable knfghgi999 is available for all countries.
# Variable knfghoi999 is available for all countries.
# Variable knncari999 is available for all countries.
# Variable knnghgi999 is available for all countries.
# Variable knnghoi999 is available for all countries.
# Variable kntcari999 is available for all countries.
# Variable kntcnai999 is available for all countries.
# Variable kntghgi999 is available for all countries.
# Variable kntghoi999 is available for all countries.
# Variable kntgnai999 is available for all countries.
# Variable kntonai999 is available for all countries.
# Variable kofcari999 is available for all countries.
# Variable kofghgi999 is available for all countries.
# Variable lcfghgi999 is available for all countries.
# Variable wedugei999 is available for all countries.
# Variable lifghgi999 is available for all countries.
# Variable lpfcari999 is available for all countries.
# Variable lpfghgi999 is available for all countries.
# Variable mcitgri999 is available for all countries.
# Variable mcomhni999 is available for all countries.
# Variable mcomnxi999 is available for all countries.
# Variable mcompxi999 is available for all countries.
# Variable mcomrxi999 is available for all countries.
# Variable mconfci999 is available for all countries.
# Variable mcwbooi999 is available for all countries.
# Variable mcwbusi999 is available for all countries.
# Variable mcwdebi999 is available for all countries.
# Variable mcwdeqi999 is available for all countries.
# Variable mcwfini999 is available for all countries.
# Variable kifghoi999 is available for all countries.
# Variable kifghgi999 is available for all countries.
# Variable kifcari999 is available for all countries.
# Variable khfghoi999 is available for all countries.
# Variable wedtgei999 is available for all countries.
# Variable wedsgei999 is available for all countries.
# Variable wedpgei999 is available for all countries.
# Variable wecogei999 is available for all countries.
# Variable wdefgei999 is available for all countries.
# Variable wcwnfai999 is available for all countries.
# Variable wcwhoui999 is available for all countries.
# Variable ghwealj992 is available for all countries.
# Variable wcwfini999 is available for all countries.
# Variable wcwdeqi999 is available for all countries.
# Variable wcwdebi999 is available for all countries.
# Variable wcwbusi999 is available for all countries.
# Variable wcwbooi999 is available for all countries.
# Variable wconfci999 is available for all countries.
# Variable wcomrxi999 is available for all countries.
# Variable wcompxi999 is available for all countries.
# Variable wcomnxi999 is available for all countries.
# Variable wcomhni999 is available for all countries.
# Variable gptincj992 is available for all countries.
# Variable wcitgri999 is available for all countries.
# Variable inyixxi999 is available for all countries.
# Variable iqualii999 is available for all countries.
# Variable kgfcari999 is available for all countries.
# Variable kgfghgi999 is available for all countries.
# Variable kgfghoi999 is available for all countries.
# Variable khfcari999 is available for all countries.
# Variable khfghdi999 is available for all countries.
# Variable khfghgi999 is available for all countries.
# Variable khfghni999 is available for all countries.
# Variable atsopxi999 is available for all countries.
# Variable atsonxi999 is available for all countries.
# Variable aptdrxi999 is available for all countries.
# Variable apwbusi992 is available for all countries.
# Variable aptfxdi999 is available for all countries.
# Variable aptfxni992 is available for all countries.
# Variable aptfxni999 is available for all countries.
# Variable aptincj992 is available for all countries.
# Variable whougei999 is available for all countries.
# Variable wheagei999 is available for all countries.
# Variable aptrrxi992 is available for all countries.
# Variable aptrrxi999 is available for all countries.
# Variable aptrxai992 is available for all countries.
# Variable aptrxai999 is available for all countries.
# Variable aptxgoi992 is available for all countries.
# Variable aptxgoi999 is available for all countries.
# Variable apwagri992 is available for all countries.
# Variable apwagri999 is available for all countries.
# Variable apwbusi999 is available for all countries.
# Variable aptfxai999 is available for all countries.
# Variable apwdebi992 is available for all countries.
# Variable apwdebi999 is available for all countries.
# Variable apweali992 is available for all countries.
# Variable apweali999 is available for all countries.
# Variable apweqii992 is available for all countries.
# Variable apweqii999 is available for all countries.
# Variable apwfini992 is available for all countries.
# Variable apwfini999 is available for all countries.
# Variable apwfiwi992 is available for all countries.
# Variable apwfiwi999 is available for all countries.
# Variable apwhoui992 is available for all countries.
# Variable apwhoui999 is available for all countries.
# Variable wgwnfai999 is available for all countries.
# Variable apwnfai992 is available for all countries.
# Variable aptfxdi992 is available for all countries.
# Variable aptfxai992 is available for all countries.
# Variable atsonxi992 is available for all countries.
# Variable aptfnxi999 is available for all countries.
# Variable aptdxai999 is available for all countries.
# Variable aptdxdi992 is available for all countries.
# Variable aptdxdi999 is available for all countries.
# Variable aptepxi992 is available for all countries.
# Variable aptepxi999 is available for all countries.
# Variable apterxi992 is available for all countries.
# Variable apterxi999 is available for all countries.
# Variable aptexai992 is available for all countries.
# Variable aptexai999 is available for all countries.
# Variable aptexdi992 is available for all countries.
# Variable aptexdi999 is available for all countries.
# Variable aptfhri992 is available for all countries.
# Variable aptfhri999 is available for all countries.
# Variable aptfnxi992 is available for all countries.
# Variable aptfoni992 is available for all countries.
# Variable aptfrxi999 is available for all countries.
# Variable aptfoni999 is available for all countries.
# Variable aptfopi992 is available for all countries.
# Variable aptfopi999 is available for all countries.
# Variable aptfori992 is available for all countries.
# Variable aptfori999 is available for all countries.
# Variable aptfpxi992 is available for all countries.
# Variable aptfpxi999 is available for all countries.
# Variable aptfrni992 is available for all countries.
# Variable aptfrni999 is available for all countries.
# Variable aptfrpi992 is available for all countries.
# Variable aptfrpi999 is available for all countries.
# Variable aptfrri992 is available for all countries.
# Variable aptfrri999 is available for all countries.
# Variable aptfrxi992 is available for all countries.
# Variable apwnfai999 is available for all countries.
# Variable apwodki992 is available for all countries.
# Variable apwodki999 is available for all countries.
# Variable atbmpxi992 is available for all countries.
# Variable ascorxi999 is available for all countries.
# Variable ascrnxi992 is available for all countries.
# Variable ascrnxi999 is available for all countries.
# Variable ascrpxi992 is available for all countries.
# Variable ascrpxi999 is available for all countries.
# Variable ascrrxi992 is available for all countries.
# Variable ascrrxi999 is available for all countries.
# Variable asopgei992 is available for all countries.
# Variable asopgei999 is available for all countries.
# Variable rdiincj992 is available for all countries.
# Variable aspigei992 is available for all countries.
# Variable aspigei999 is available for all countries.
# Variable ataxnxi992 is available for all countries.
# Variable ataxnxi999 is available for all countries.
# Variable atbmpxi999 is available for all countries.
# Variable wgwhoui999 is available for all countries.
# Variable atbnnxi992 is available for all countries.
# Variable atbnnxi999 is available for all countries.
# Variable atbxrxi992 is available for all countries.
# Variable atbxrxi999 is available for all countries.
# Variable atgmpxi992 is available for all countries.
# Variable atgmpxi999 is available for all countries.
# Variable atgnnxi992 is available for all countries.
# Variable atgnnxi999 is available for all countries.
# Variable atgxrxi992 is available for all countries.
# Variable atgxrxi999 is available for all countries.
# Variable atsmpxi992 is available for all countries.
# Variable atsmpxi999 is available for all countries.
# Variable atsnnxi992 is available for all countries.
# Variable atsnnxi999 is available for all countries.
# Variable ascorxi992 is available for all countries.
# Variable ascopxi999 is available for all countries.
# Variable ascopxi992 is available for all countries.
# Variable asconxi999 is available for all countries.
# Variable apwpeni992 is available for all countries.
# Variable apwpeni999 is available for all countries.
# Variable apwtgri992 is available for all countries.
# Variable apwtgri999 is available for all countries.
# Variable arecgei992 is available for all countries.
# Variable arecgei999 is available for all countries.
# Variable aretgoi992 is available for all countries.
# Variable aretgoi999 is available for all countries.
# Variable arevgoi992 is available for all countries.
# Variable arevgoi999 is available for all countries.
# Variable asacgei992 is available for all countries.
# Variable asacgei999 is available for all countries.
# Variable asakgei992 is available for all countries.
# Variable asakgei999 is available for all countries.
# Variable ascgnxi992 is available for all countries.
# Variable ascgnxi999 is available for all countries.
# Variable ascgpxi992 is available for all countries.
# Variable ascgpxi999 is available for all countries.
# Variable ascgrxi992 is available for all countries.
# Variable ascgrxi999 is available for all countries.
# Variable ascinxi992 is available for all countries.
# Variable ascinxi999 is available for all countries.
# Variable ascipxi992 is available for all countries.
# Variable ascipxi999 is available for all countries.
# Variable ascirxi992 is available for all countries.
# Variable ascirxi999 is available for all countries.
# Variable ascogri992 is available for all countries.
# Variable ascogri999 is available for all countries.
# Variable asconxi992 is available for all countries.
# Variable mcwhoui999 is available for all countries.
# Variable mcwnfai999 is available for all countries.
# Variable mdefgei999 is available for all countries.
# Variable npopulf998 is available for all countries.
# Variable npopulf751 is available for all countries.
# Variable npopulf801 is available for all countries.
# Variable npopulf802 is available for all countries.
# Variable npopulf851 is available for all countries.
# Variable npopulf901 is available for all countries.
# Variable npopulf902 is available for all countries.
# Variable npopulf951 is available for all countries.
# Variable npopulf991 is available for all countries.
# Variable npopulf992 is available for all countries.
# Variable npopulf993 is available for all countries.
# Variable npopulf994 is available for all countries.
# Variable npopulf995 is available for all countries.
# Variable npopulf996 is available for all countries.
# Variable npopulf997 is available for all countries.
# Variable npopulf999 is available for all countries.
# Variable npopulf701 is available for all countries.
# Variable npopuli001 is available for all countries.
# Variable npopuli014 is available for all countries.
# Variable npopuli051 is available for all countries.
# Variable npopuli101 is available for all countries.
# Variable npopuli111 is available for all countries.
# Variable npopuli151 is available for all countries.
# Variable npopuli156 is available for all countries.
# Variable npopuli201 is available for all countries.
# Variable npopuli202 is available for all countries.
# Variable npopuli251 is available for all countries.
# Variable npopuli301 is available for all countries.
# Variable npopuli302 is available for all countries.
# Variable npopuli351 is available for all countries.
# Variable npopuli401 is available for all countries.
# Variable npopulf702 is available for all countries.
# Variable npopulf651 is available for all countries.
# Variable mecogei999 is available for all countries.
# Variable npopulf111 is available for all countries.
# Variable mtsonxi999 is available for all countries.
# Variable mtsopxi999 is available for all countries.
# Variable mtsorxi999 is available for all countries.
# Variable mtstnxi999 is available for all countries.
# Variable mtstpxi999 is available for all countries.
# Variable mtstrxi999 is available for all countries.
# Variable mtsvnxi999 is available for all countries.
# Variable mtsvpxi999 is available for all countries.
# Variable mtsvrxi999 is available for all countries.
# Variable mtsxrxi999 is available for all countries.
# Variable npopulf001 is available for all countries.
# Variable npopulf014 is available for all countries.
# Variable npopulf051 is available for all countries.
# Variable npopulf101 is available for all countries.
# Variable npopulf151 is available for all countries.
# Variable npopulf602 is available for all countries.
# Variable npopulf156 is available for all countries.
# Variable npopulf201 is available for all countries.
# Variable npopulf202 is available for all countries.
# Variable npopulf251 is available for all countries.
# Variable npopulf301 is available for all countries.
# Variable npopulf302 is available for all countries.
# Variable npopulf351 is available for all countries.
# Variable npopulf401 is available for all countries.
# Variable npopulf402 is available for all countries.
# Variable npopulf451 is available for all countries.
# Variable npopulf501 is available for all countries.
# Variable npopulf502 is available for all countries.
# Variable npopulf551 is available for all countries.
# Variable npopulf601 is available for all countries.
# Variable npopuli402 is available for all countries.
# Variable npopuli451 is available for all countries.
# Variable npopuli501 is available for all countries.
# Variable npopulm801 is available for all countries.
# Variable npopulm302 is available for all countries.
# Variable npopulm351 is available for all countries.
# Variable npopulm401 is available for all countries.
# Variable npopulm402 is available for all countries.
# Variable npopulm451 is available for all countries.
# Variable npopulm501 is available for all countries.
# Variable npopulm502 is available for all countries.
# Variable npopulm551 is available for all countries.
# Variable npopulm601 is available for all countries.
# Variable npopulm602 is available for all countries.
# Variable npopulm651 is available for all countries.
# Variable npopulm701 is available for all countries.
# Variable npopulm702 is available for all countries.
# Variable npopulm751 is available for all countries.
# Variable npopulm802 is available for all countries.
# Variable npopuli502 is available for all countries.
# Variable npopulm851 is available for all countries.
# Variable npopulm901 is available for all countries.
# Variable npopulm902 is available for all countries.
# Variable npopulm951 is available for all countries.
# Variable npopulm991 is available for all countries.
# Variable npopulm992 is available for all countries.
# Variable npopulm993 is available for all countries.
# Variable npopulm994 is available for all countries.
# Variable npopulm995 is available for all countries.
# Variable npopulm996 is available for all countries.
# Variable npopulm997 is available for all countries.
# Variable npopulm998 is available for all countries.
# Variable npopulm999 is available for all countries.
# Variable rptincj992 is available for all countries.
# Variable npopulm301 is available for all countries.
# Variable npopulm251 is available for all countries.
# Variable npopulm202 is available for all countries.
# Variable npopulm201 is available for all countries.
# Variable npopuli551 is available for all countries.
# Variable npopuli601 is available for all countries.
# Variable npopuli602 is available for all countries.
# Variable npopuli651 is available for all countries.
# Variable npopuli701 is available for all countries.
# Variable npopuli702 is available for all countries.
# Variable npopuli751 is available for all countries.
# Variable npopuli801 is available for all countries.
# Variable npopuli802 is available for all countries.
# Variable npopuli851 is available for all countries.
# Variable npopuli901 is available for all countries.
# Variable npopuli902 is available for all countries.
# Variable npopuli951 is available for all countries.
# Variable npopuli991 is available for all countries.
# Variable npopuli992 is available for all countries.
# Variable npopuli993 is available for all countries.
# Variable npopuli994 is available for all countries.
# Variable npopuli995 is available for all countries.
# Variable npopuli996 is available for all countries.
# Variable npopuli997 is available for all countries.
# Variable npopuli998 is available for all countries.
# Variable npopuli999 is available for all countries.
# Variable npopulm001 is available for all countries.
# Variable npopulm014 is available for all countries.
# Variable npopulm051 is available for all countries.
# Variable npopulm101 is available for all countries.
# Variable npopulm111 is available for all countries.
# Variable npopulm151 is available for all countries.
# Variable npopulm156 is available for all countries.
# Variable mtsnnxi999 is available for all countries.
# Variable mtsmpxi999 is available for all countries.
# Variable mtgxrxi999 is available for all countries.
# Variable mntrgri999 is available for all countries.
# Variable mheagei999 is available for all countries.
# Variable mhougei999 is available for all countries.
# Variable mhweali999 is available for all countries.
# Variable tdiincj992 is available for all countries.
# Variable minpgoi999 is available for all countries.
# Variable mintgri999 is available for all countries.
# Variable miweali999 is available for all countries.
# Variable sptincj992 is available for all countries.
# Variable spllinf992 is available for all countries.
# Variable shwealj992 is available for all countries.
# Variable mncanxi999 is available for all countries.
# Variable mndproi999 is available for all countries.
# Variable mnnfini999 is available for all countries.
# Variable mnninci999 is available for all countries.
# Variable mnwagri999 is available for all countries.
# Variable mpinrxi999 is available for all countries.
# Variable mnwbooi999 is available for all countries.
# Variable mnwbusi999 is available for all countries.
# Variable mnweali999 is available for all countries.
# Variable mnwgxai999 is available for all countries.
# Variable mnwgxdi999 is available for all countries.
# Variable mnwhoui999 is available for all countries.
# Variable mnwnfai999 is available for all countries.
# Variable mnwnxai999 is available for all countries.
# Variable mnwoffi999 is available for all countries.
# Variable mopinxi999 is available for all countries.
# Variable mopipxi999 is available for all countries.
# Variable mopirxi999 is available for all countries.
# Variable mottgri999 is available for all countries.
# Variable mpinnxi999 is available for all countries.
# Variable mgwnfai999 is available for all countries.
# Variable mgwhoui999 is available for all countries.
# Variable mgwfini999 is available for all countries.
# Variable mgweali999 is available for all countries.
# Variable medpgei999 is available for all countries.
# Variable medsgei999 is available for all countries.
# Variable medtgei999 is available for all countries.
# Variable medugei999 is available for all countries.
# Variable menvgei999 is available for all countries.
# Variable mexpgoi999 is available for all countries.
# Variable mfdinxi999 is available for all countries.
# Variable mfdipxi999 is available for all countries.
# Variable mfdirxi999 is available for all countries.
# Variable mfdixai999 is available for all countries.
# Variable mfdixdi999 is available for all countries.
# Variable mfdixni999 is available for all countries.
# Variable mfinpxi999 is available for all countries.
# Variable mfinrxi999 is available for all countries.
# Variable mfkanxi999 is available for all countries.
# Variable mfkapxi999 is available for all countries.
# Variable mfkarxi999 is available for all countries.
# Variable mflcini999 is available for all countries.
# Variable mflcipi999 is available for all countries.
# Variable mflciri999 is available for all countries.
# Variable tptincj992 is available for all countries.
# Variable thwealj992 is available for all countries.
# Variable mfsubxi999 is available for all countries.
# Variable mftaxxi999 is available for all countries.
# Variable mgdproi999 is available for all countries.
# Variable mgninci999 is available for all countries.
# Variable mgpsgei999 is available for all countries.
# Variable mgwbusi999 is available for all countries.
# Variable mgwdebi999 is available for all countries.
# Variable mpinpxi999 is available for all countries.
# Variable mpitgri999 is available for all countries.
# Variable mtgnnxi999 is available for all countries.
# Variable mscipxi999 is available for all countries.
# Variable mpwnfai999 is available for all countries.
# Variable mpwodki999 is available for all countries.
# Variable sdiincj992 is available for all countries.
# Variable mpwpeni999 is available for all countries.
# Variable mpwtgri999 is available for all countries.
# Variable mrecgei999 is available for all countries.
# Variable mretgoi999 is available for all countries.
# Variable mrevgoi999 is available for all countries.
# Variable msacgei999 is available for all countries.
# Variable msakgei999 is available for all countries.
# Variable mscgnxi999 is available for all countries.
# Variable mscgpxi999 is available for all countries.
# Variable mscgrxi999 is available for all countries.
# Variable mscinxi999 is available for all countries.
# Variable mscirxi999 is available for all countries.
# Variable mpolgei999 is available for all countries.
# Variable mscogri999 is available for all countries.
# Variable msconxi999 is available for all countries.
# Variable mscopxi999 is available for all countries.
# Variable mscorxi999 is available for all countries.
# Variable mscrnxi999 is available for all countries.
# Variable mscrpxi999 is available for all countries.
# Variable mscrrxi999 is available for all countries.
# Variable msopgei999 is available for all countries.
# Variable mspigei999 is available for all countries.
# Variable mtaxnxi999 is available for all countries.
# Variable mtbmpxi999 is available for all countries.
# Variable mtbnnxi999 is available for all countries.
# Variable mtbxrxi999 is available for all countries.
# Variable mtgmpxi999 is available for all countries.
# Variable mpwhoui999 is available for all countries.
# Variable mpwfiwi999 is available for all countries.
# Variable mpwfini999 is available for all countries.
# Variable mpweqii999 is available for all countries.
# Variable mpsugoi999 is available for all countries.
# Variable mptdpxi999 is available for all countries.
# Variable mptdrxi999 is available for all countries.
# Variable mptdxai999 is available for all countries.
# Variable mptdxdi999 is available for all countries.
# Variable mptepxi999 is available for all countries.
# Variable mpterxi999 is available for all countries.
# Variable mptexai999 is available for all countries.
# Variable mptexdi999 is available for all countries.
# Variable mptfhri999 is available for all countries.
# Variable mptfnxi999 is available for all countries.
# Variable mptfoni999 is available for all countries.
# Variable mptfopi999 is available for all countries.
# Variable mptfori999 is available for all countries.
# Variable mptfpxi999 is available for all countries.
# Variable mptfrni999 is available for all countries.
# Variable mptfrpi999 is available for all countries.
# Variable mptfrri999 is available for all countries.
# Variable mptfrxi999 is available for all countries.
# Variable mptfxai999 is available for all countries.
# Variable mptfxdi999 is available for all countries.
# Variable mptfxni999 is available for all countries.
# Variable mptrrxi999 is available for all countries.
# Variable mptrxai999 is available for all countries.
# Variable mptxgoi999 is available for all countries.
# Variable mpwagri999 is available for all countries.
# Variable mpwbusi999 is available for all countries.
# Variable mpwdebi999 is available for all countries.
# Variable mpweali999 is available for all countries.
# Variable aptdxai992 is available for all countries.
# Variable rhwealj992 is available for all countries.
# Variable aptdrxi992 is available for all countries.
# Variable aenvgei999 is available for all countries.
# Variable wspigei999 is available for all countries.
# Variable wtaxnxi999 is available for all countries.
# Variable wtbmpxi999 is available for all countries.
# Variable wtbnnxi999 is available for all countries.
# Variable wtbxrxi999 is available for all countries.
# Variable aexpgoi999 is available for all countries.
# Variable aexpgoi992 is available for all countries.
# Variable aenvgei992 is available for all countries.
# Variable agwnfai999 is available for all countries.
# Variable aedugei999 is available for all countries.
# Variable aedugei992 is available for all countries.
# Variable aedtgei999 is available for all countries.
# Variable aedtgei992 is available for all countries.
# Variable aedsgei999 is available for all countries.
# Variable aedsgei992 is available for all countries.
# Variable aedpgei999 is available for all countries.
# Variable wsopgei999 is available for all countries.
# Variable wscogri999 is available for all countries.
# Variable wscirxi999 is available for all countries.
# Variable wncanxi999 is available for all countries.
# Variable aheagei999 is available for all countries.
# Variable ahougei992 is available for all countries.
# Variable ahougei999 is available for all countries.
# Variable afdinxi992 is available for all countries.
# Variable wscipxi999 is available for all countries.
# Variable wnwgxai999 is available for all countries.
# Variable wnweali999 is available for all countries.
# Variable wnwbusi999 is available for all countries.
# Variable wnwbooi999 is available for all countries.
# Variable ahweali992 is available for all countries.
# Variable wnwagri999 is available for all countries.
# Variable ahweali999 is available for all countries.
# Variable ahwealj992 is available for all countries.
# Variable wnnfini999 is available for all countries.
# Variable wndproi999 is available for all countries.
# Variable aedpgei992 is available for all countries.
# Variable ainpgoi992 is available for all countries.
# Variable ainpgoi999 is available for all countries.
# Variable xlceuxi999 is available for all countries.
# Variable xlcusxi999 is available for all countries.
# Variable xlcyupi999 is available for all countries.
# Variable wintgri999 is available for all countries.
# Variable ancanxi992 is available for all countries.
# Variable ancanxi999 is available for all countries.
# Variable andproi992 is available for all countries.
# Variable andproi999 is available for all countries.
# Variable annfini992 is available for all countries.
# Variable annfini999 is available for all countries.
# Variable anninci992 is available for all countries.
# Variable anninci999 is available for all countries.
# Variable antrgri992 is available for all countries.
# Variable antrgri999 is available for all countries.
# Variable aconfci999 is available for all countries.
# Variable aconfci992 is available for all countries.
# Variable xlcuspi999 is available for all countries.
# Variable xlceupi999 is available for all countries.
# Variable aintgri992 is available for all countries.
# Variable wwealpi999 is available for all countries.
# Variable aintgri999 is available for all countries.
# Variable wiweali999 is available for all countries.
# Variable aecogei999 is available for all countries.
# Variable aecogei992 is available for all countries.
# Variable wtgmpxi999 is available for all countries.
# Variable wtgnnxi999 is available for all countries.
# Variable wtgxrxi999 is available for all countries.
# Variable adiincj992 is available for all countries.
# Variable wtsnnxi999 is available for all countries.
# Variable wtsxrxi999 is available for all countries.
# Variable wwealgi999 is available for all countries.
# Variable wwealhi999 is available for all countries.
# Variable wwealni999 is available for all countries.
# Variable adefgei999 is available for all countries.
# Variable adefgei992 is available for all countries.
# Variable aheagei992 is available for all countries.
# Variable agwnfai992 is available for all countries.
# Variable acomrxi992 is available for all countries.
# Variable afkarxi992 is available for all countries.
# Variable agdproi992 is available for all countries.
# Variable agdproi999 is available for all countries.
# Variable agninci992 is available for all countries.
# Variable agninci999 is available for all countries.
# Variable agpsgei992 is available for all countries.
# Variable agpsgei999 is available for all countries.
# Variable afkarxi999 is available for all countries.
# Variable afkapxi999 is available for all countries.
# Variable wnwgxdi999 is available for all countries.
# Variable afkapxi992 is available for all countries.
# Variable afkanxi999 is available for all countries.
# Variable afkanxi992 is available for all countries.
# Variable wptfpxi999 is available for all countries.
# Variable wptfrxi999 is available for all countries.
# Variable wpwagri999 is available for all countries.
# Variable afinrxi999 is available for all countries.
# Variable aflcini992 is available for all countries.
# Variable aflcini999 is available for all countries.
# Variable aftaxxi999 is available for all countries.
# Variable aflcipi992 is available for all countries.
# Variable aflciri999 is available for all countries.
# Variable wptfnxi999 is available for all countries.
# Variable wpolgei999 is available for all countries.
# Variable wpitgri999 is available for all countries.
# Variable wpinrxi999 is available for all countries.
# Variable wpinpxi999 is available for all countries.
# Variable wpinnxi999 is available for all countries.
# Variable wottgri999 is available for all countries.
# Variable wnwnxai999 is available for all countries.
# Variable wnwnfai999 is available for all countries.
# Variable aflciri992 is available for all countries.
# Variable aflcipi999 is available for all countries.
# Variable afsubxi992 is available for all countries.
# Variable afsubxi999 is available for all countries.
# Variable aftaxxi992 is available for all countries.
# Variable afinrxi992 is available for all countries.
# Variable afinpxi999 is available for all countries.
# Variable afinpxi992 is available for all countries.
# Variable wsakgei999 is available for all countries.
# Variable afdixni999 is available for all countries.
# Variable afdixni992 is available for all countries.
# Variable afdixdi999 is available for all countries.
# Variable agwfini992 is available for all countries.
# Variable afdixdi992 is available for all countries.
# Variable afdixai999 is available for all countries.
# Variable afdixai992 is available for all countries.
# Variable afdirxi999 is available for all countries.
# Variable agwfini999 is available for all countries.
# Variable aptdpxi999 is available for all countries.
# Variable afdirxi992 is available for all countries.
# Variable afdipxi999 is available for all countries.
# Variable afdipxi992 is available for all countries.
# Variable afdinxi999 is available for all countries.
# Variable wnwhoui999 is available for all countries.
# Variable wscinxi999 is available for all countries.
# Variable agweali999 is available for all countries.
# Variable wpwbusi999 is available for all countries.
# Variable agweali992 is available for all countries.
# Variable wpwdebi999 is available for all countries.
# Variable wpweali999 is available for all countries.
# Variable wpweqii999 is available for all countries.
# Variable wpwfini999 is available for all countries.
# Variable wpwfiwi999 is available for all countries.
# Variable wpwhoui999 is available for all countries.
# Variable wpwnfai999 is available for all countries.
# Variable wpwodki999 is available for all countries.
# Variable wpwpeni999 is available for all countries.
# Variable wpwtgri999 is available for all countries.
# Variable wrecgei999 is available for all countries.
# Variable wrevgoi999 is available for all countries.
# Variable wsacgei999 is available for all countries.
# Variable agwdebi992 is available for all countries.
# Variable agwdebi999 is available for all countries.
# Variable acomrxi999 is available for all countries.
# Variable wtsmpxi999 is available for all countries.
# Variable acompxi999 is available for all countries.
# Variable acitgri999 is available for all countries.
# Variable anwoffi992 is available for all countries.
# Variable acitgri992 is available for all countries.
# Variable acompxi992 is available for all countries.
# Variable apinpxi992 is available for all countries.
# Variable apinpxi999 is available for all countries.
# Variable anweali999 is available for all countries.
# Variable apinrxi992 is available for all countries.
# Variable apinrxi999 is available for all countries.
# Variable apitgri992 is available for all countries.
# Variable acomhni992 is available for all countries.
# Variable anwnxai999 is available for all countries.
# Variable anwnxai992 is available for all countries.
# Variable anwnfai999 is available for all countries.
# Variable anwnfai992 is available for all countries.
# Variable apitgri999 is available for all countries.
# Variable acomnxi999 is available for all countries.
# Variable anwgxdi999 is available for all countries.
# Variable apolgei992 is available for all countries.
# Variable anwgxdi992 is available for all countries.
# Variable anwgxai999 is available for all countries.
# Variable anwgxai992 is available for all countries.
# Variable acomnxi992 is available for all countries.
# Variable apolgei999 is available for all countries.
# Variable anwoffi999 is available for all countries.
# Variable acomhni999 is available for all countries.
# Variable aopirxi992 is available for all countries.
# Variable apsugoi999 is available for all countries.
# Variable aopinxi992 is available for all countries.
# Variable aopipxi999 is available for all countries.
# Variable aopipxi992 is available for all countries.
# Variable aopirxi999 is available for all countries.
# Variable anweali992 is available for all countries.
# Variable aottgri992 is available for all countries.
# Variable aptdpxi992 is available for all countries.
# Variable aopinxi999 is available for all countries.
# Variable aottgri999 is available for all countries.
# Variable apsugoi992 is available for all countries.
# Variable apinnxi999 is available for all countries.
# Variable whweali999 is available for all countries.
# Variable apinnxi992 is available for all countries.

# %%
print(variable_availability.head())
